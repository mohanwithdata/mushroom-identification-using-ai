# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Input
import os

# %%
# Set dataset path
data_dir = r'D:\Project\aug_data\data_aug'

# %%
batch_size = 32
img_height = 224
img_width = 224
image_size = (img_height, img_width)
epochs = int(input("Enter epochs number: "))
# Out:
# Enter epochs number:  20

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb'  # Force RGB mode
)
# Out:
# Found 1314 images belonging to 7 classes.

# %%
val_data = r"D:\Project\aug_data\paper_data"

# %%
val_generator = train_datagen.flow_from_directory(
    val_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
)
# Out:
# Found 438 images belonging to 7 classes.

# %%
model = Sequential([
    Input(shape=(224, 224, 3)),  # Define input explicitly
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(256, activation='relu'),
    Dense(len(train_generator.class_indices), activation='softmax')  # Output layer
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 86528)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               22151424
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 1799
# =================================================================
# Total params: 22,246,471
# Trainable params: 22,246,471
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)
# Out:
# Epoch 1/20
# 42/42 [==============================] - 64s 1s/step - loss: 1.4029 - accuracy: 0.4802 - val_loss: 0.9718 - val_accuracy: 0.6781
# Epoch 2/20
# 42/42 [==============================] - 49s 1s/step - loss: 0.5882 - accuracy: 0.7686 - val_loss: 0.3898 - val_accuracy: 0.8447
# Epoch 3/20
# 42/42 [==============================] - 56s 1s/step - loss: 0.3904 - accuracy: 0.8501 - val_loss: 0.4911 - val_accuracy: 0.7922
# Epoch 4/20
# 42/42 [==============================] - 56s 1s/step - loss: 0.3005 - accuracy: 0.8935 - val_loss: 0.3035 - val_accuracy: 0.8881
# Epoch 5/20
# 42/42 [==============================] - 49s 1s/step - loss: 0.2253 - accuracy: 0.9140 - val_loss: 0.1485 - val_accuracy: 0.9384
# Epoch 6/20
# 42/42 [==============================] - 56s 1s/step - loss: 0.1871 - accuracy: 0.9216 - val_loss: 0.1699 - val_accuracy: 0.9269
# Epoch 7/20
# 42/42 [==============================] - 56s 1s/step - loss: 0.1761 - accuracy: 0.9384 - val_loss: 0.1238 - val_accuracy: 0.9429
# Epoch 8/20
# 42/42 [==============================] - 57s 1s/step - loss: 0.1200 - accuracy: 0.9619 - val_loss: 0.1970 - val_accuracy: 0.9247
# Epoch 9/20
# 42/42 [==============================] - 56s 1s/step - loss: 0.1749 - accuracy: 0.9452 - val_loss: 0.0890 - val_accuracy: 0.9772
# Epoch 10/20
# 42/42 [==============================] - 49s 1s/step - loss: 0.0656 - accuracy: 0.9772 - val_loss: 0.0252 - val_accuracy: 0.9909
# Epoch 11/20
# 42/42 [==============================] - 56s 1s/step - loss: 0.0620 - accuracy: 0.9848 - val_loss: 0.0618 - val_accuracy: 0.9909
# Epoch 12/20
# 42/42 [==============================] - 48s 1s/step - loss: 0.0847 - accuracy: 0.9749 - val_loss: 0.0451 - val_accuracy: 0.9863
# Epoch 13/20
# 42/42 [==============================] - 55s 1s/step - loss: 0.1120 - accuracy: 0.9627 - val_loss: 0.0464 - val_accuracy: 0.9886
# Epoch 14/20
# 42/42 [==============================] - 55s 1s/step - loss: 0.0469 - accuracy: 0.9878 - val_loss: 0.0178 - val_accuracy: 0.9977
# Epoch 15/20
# 42/42 [==============================] - 56s 1s/step - loss: 0.0296 - accuracy: 0.9916 - val_loss: 0.0144 - val_accuracy: 0.9954
# Epoch 16/20
# 42/42 [==============================] - 55s 1s/step - loss: 0.0393 - accuracy: 0.9916 - val_loss: 0.0367 - val_accuracy: 0.9863
# Epoch 17/20
# 42/42 [==============================] - 56s 1s/step - loss: 0.0284 - accuracy: 0.9924 - val_loss: 0.0402 - val_accuracy: 0.9795
# Epoch 18/20
# 42/42 [==============================] - 55s 1s/step - loss: 0.0161 - accuracy: 0.9932 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 19/20
# 42/42 [==============================] - 47s 1s/step - loss: 0.0106 - accuracy: 0.9962 - val_loss: 0.0177 - val_accuracy: 0.9932
# Epoch 20/20
# 42/42 [==============================] - 56s 1s/step - loss: 0.0134 - accuracy: 0.9970 - val_loss: 0.0034 - val_accuracy: 1.0000

# %%
# Plot accuracy and loss curves
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
# Evaluate model
eval_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

y_true = eval_generator.classes
y_pred = model.predict(eval_generator)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)  # Fix tf.argmax issue
# Out:
# Found 1314 images belonging to 7 classes.

# %%
# Print classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred_classes))

# Plot confusion matrix
conf_mat = confusion_matrix(y_true, y_pred_classes)
class_labels = list(train_generator.class_indices.keys())
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       198
#            1       1.00      1.00      1.00       186
#            2       1.00      1.00      1.00       201
#            3       1.00      1.00      1.00       183
#            4       1.00      1.00      1.00       180
#            5       1.00      1.00      1.00       183
#            6       1.00      1.00      1.00       183
#
#     accuracy                           1.00      1314
#    macro avg       1.00      1.00      1.00      1314
# weighted avg       1.00      1.00      1.00      1314

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="viridis", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('Actual', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)
plt.show()

# %%
model_version = epochs
next_version = str(int(model_version) + 10)

# %%
import shutil

notebook_filename = f"CNN_{model_version}_ADAM_aug.ipynb"
new_notebook_filename = f"CNN_{next_version}_ADAM_aug.ipynb"

shutil.copy(notebook_filename, new_notebook_filename)
print(f"Notebook copied as {new_notebook_filename}")
# Out:
# Notebook copied as CNN_30_ADAM_aug.ipynb

# %%
os._exit(00)
