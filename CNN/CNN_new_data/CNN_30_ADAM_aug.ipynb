# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Input
import os

# %%
# Set dataset path
data_dir = r'D:\Project\aug_data\data_aug'

# %%
batch_size = 32
img_height = 224
img_width = 224
image_size = (img_height, img_width)
epochs = int(input("Enter epochs number: "))
# Out:
# Enter epochs number:  30

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb'  # Force RGB mode
)
# Out:
# Found 1314 images belonging to 7 classes.

# %%
val_data = r"D:\Project\aug_data\paper_data"

# %%
val_generator = train_datagen.flow_from_directory(
    val_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
)
# Out:
# Found 438 images belonging to 7 classes.

# %%
model = Sequential([
    Input(shape=(224, 224, 3)),  # Define input explicitly
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(256, activation='relu'),
    Dense(len(train_generator.class_indices), activation='softmax')  # Output layer
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 86528)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               22151424
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 1799
# =================================================================
# Total params: 22,246,471
# Trainable params: 22,246,471
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)
# Out:
# Epoch 1/30
# 42/42 [==============================] - 68s 1s/step - loss: 1.6585 - accuracy: 0.4201 - val_loss: 0.9384 - val_accuracy: 0.7078
# Epoch 2/30
# 42/42 [==============================] - 49s 1s/step - loss: 0.6060 - accuracy: 0.7816 - val_loss: 0.4317 - val_accuracy: 0.8516
# Epoch 3/30
# 42/42 [==============================] - 46s 1s/step - loss: 0.4083 - accuracy: 0.8554 - val_loss: 0.2671 - val_accuracy: 0.9064
# Epoch 4/30
# 42/42 [==============================] - 47s 1s/step - loss: 0.2320 - accuracy: 0.9132 - val_loss: 0.2505 - val_accuracy: 0.8995
# Epoch 5/30
# 42/42 [==============================] - 56s 1s/step - loss: 0.4625 - accuracy: 0.8409 - val_loss: 0.1897 - val_accuracy: 0.9315
# Epoch 6/30
# 42/42 [==============================] - 56s 1s/step - loss: 0.2240 - accuracy: 0.9163 - val_loss: 0.3145 - val_accuracy: 0.8813
# Epoch 7/30
# 42/42 [==============================] - 43s 1s/step - loss: 0.1536 - accuracy: 0.9482 - val_loss: 0.0659 - val_accuracy: 0.9840
# Epoch 8/30
# 42/42 [==============================] - 46s 1s/step - loss: 0.1541 - accuracy: 0.9528 - val_loss: 0.1271 - val_accuracy: 0.9429
# Epoch 9/30
# 42/42 [==============================] - 48s 1s/step - loss: 0.0927 - accuracy: 0.9680 - val_loss: 0.0311 - val_accuracy: 0.9932
# Epoch 10/30
# 42/42 [==============================] - 48s 1s/step - loss: 0.0748 - accuracy: 0.9787 - val_loss: 0.0830 - val_accuracy: 0.9703
# Epoch 11/30
# 42/42 [==============================] - 55s 1s/step - loss: 0.1619 - accuracy: 0.9444 - val_loss: 0.1114 - val_accuracy: 0.9612
# Epoch 12/30
# 42/42 [==============================] - 48s 1s/step - loss: 0.0753 - accuracy: 0.9749 - val_loss: 0.0230 - val_accuracy: 0.9954
# Epoch 13/30
# 42/42 [==============================] - 56s 1s/step - loss: 0.0664 - accuracy: 0.9787 - val_loss: 0.0367 - val_accuracy: 0.9886
# Epoch 14/30
# 42/42 [==============================] - 48s 1s/step - loss: 0.0738 - accuracy: 0.9734 - val_loss: 0.0487 - val_accuracy: 0.9817
# Epoch 15/30
# 42/42 [==============================] - 56s 1s/step - loss: 0.0328 - accuracy: 0.9893 - val_loss: 0.0173 - val_accuracy: 0.9954
# Epoch 16/30
# 42/42 [==============================] - 58s 1s/step - loss: 0.0378 - accuracy: 0.9840 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 17/30
# 42/42 [==============================] - 55s 1s/step - loss: 0.0753 - accuracy: 0.9795 - val_loss: 0.0235 - val_accuracy: 0.9909
# Epoch 18/30
# 42/42 [==============================] - 56s 1s/step - loss: 0.0241 - accuracy: 0.9916 - val_loss: 0.0236 - val_accuracy: 0.9932
# Epoch 19/30
# 42/42 [==============================] - 55s 1s/step - loss: 0.0094 - accuracy: 0.9977 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 20/30
# 42/42 [==============================] - 55s 1s/step - loss: 0.0034 - accuracy: 0.9985 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 21/30
# 42/42 [==============================] - 48s 1s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 0.9977
# Epoch 22/30
# 42/42 [==============================] - 48s 1s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 23/30
# 42/42 [==============================] - 49s 1s/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 0.0031 - val_accuracy: 0.9977
# Epoch 24/30
# 42/42 [==============================] - 49s 1s/step - loss: 8.2519e-04 - accuracy: 1.0000 - val_loss: 8.7030e-04 - val_accuracy: 1.0000
# Epoch 25/30
# 42/42 [==============================] - 48s 1s/step - loss: 5.9410e-04 - accuracy: 1.0000 - val_loss: 6.2407e-04 - val_accuracy: 1.0000
# Epoch 26/30
# 42/42 [==============================] - 48s 1s/step - loss: 5.1439e-04 - accuracy: 1.0000 - val_loss: 9.8919e-04 - val_accuracy: 1.0000
# Epoch 27/30
# 42/42 [==============================] - 56s 1s/step - loss: 5.9028e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 28/30
# 42/42 [==============================] - 55s 1s/step - loss: 0.0093 - accuracy: 0.9977 - val_loss: 0.0159 - val_accuracy: 0.9909
# Epoch 29/30
# 42/42 [==============================] - 48s 1s/step - loss: 0.0959 - accuracy: 0.9741 - val_loss: 0.0700 - val_accuracy: 0.9749
# Epoch 30/30
# 42/42 [==============================] - 56s 1s/step - loss: 0.0317 - accuracy: 0.9893 - val_loss: 0.0471 - val_accuracy: 0.9863

# %%
# Plot accuracy and loss curves
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
# Evaluate model
eval_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

y_true = eval_generator.classes
y_pred = model.predict(eval_generator)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)  # Fix tf.argmax issue
# Out:
# Found 1314 images belonging to 7 classes.

# %%
# Print classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred_classes))

# Plot confusion matrix
conf_mat = confusion_matrix(y_true, y_pred_classes)
class_labels = list(train_generator.class_indices.keys())
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       198
#            1       0.99      0.99      0.99       186
#            2       1.00      1.00      1.00       201
#            3       0.94      1.00      0.97       183
#            4       0.99      0.99      0.99       180
#            5       1.00      1.00      1.00       183
#            6       1.00      0.93      0.96       183
#
#     accuracy                           0.99      1314
#    macro avg       0.99      0.99      0.99      1314
# weighted avg       0.99      0.99      0.99      1314

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="viridis", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('Actual', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)
plt.show()

# %%
model_version = epochs
next_version = str(int(model_version) + 10)

# %%
import shutil

notebook_filename = f"CNN_{model_version}_ADAM_aug.ipynb"
new_notebook_filename = f"CNN_{next_version}_ADAM_aug.ipynb"

shutil.copy(notebook_filename, new_notebook_filename)
print(f"Notebook copied as {new_notebook_filename}")
# Out:
# Notebook copied as CNN_40_ADAM_aug.ipynb

# %%
os._exit(00)
