# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Input
import os

# %%
# Set dataset path
data_dir = r'D:\Project\data_kaggle\aug\train_split'

# %%
batch_size = 32
img_height = 224
img_width = 224
image_size = (img_height, img_width)
epochs = int(input("Enter epochs number: "))
# Out:
# Enter epochs number:  50

# %%
train_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb'  # Force RGB mode
)
# Out:
# Found 5863 images belonging to 8 classes.

# %%
val_datagen = ImageDataGenerator()

val_data = r"D:\Project\data_kaggle\aug\val_split"

val_generator = val_datagen.flow_from_directory(
    val_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
)
# Out:
# Found 1469 images belonging to 8 classes.

# %%
model = Sequential([
    Input(shape=(224, 224, 3)),  # Define input explicitly
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(256, activation='relu'),
    Dense(len(train_generator.class_indices), activation='softmax')  # Output layer
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 86528)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               22151424
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 22,246,728
# Trainable params: 22,246,728
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)
# Out:
# Epoch 1/50
# 184/184 [==============================] - 67s 290ms/step - loss: 24.5353 - accuracy: 0.2373 - val_loss: 2.0474 - val_accuracy: 0.1620
# Epoch 2/50
# 184/184 [==============================] - 48s 261ms/step - loss: 1.9034 - accuracy: 0.2847 - val_loss: 1.9848 - val_accuracy: 0.3131
# Epoch 3/50
# 184/184 [==============================] - 49s 266ms/step - loss: 1.7075 - accuracy: 0.4018 - val_loss: 1.8372 - val_accuracy: 0.3458
# Epoch 4/50
# 184/184 [==============================] - 48s 260ms/step - loss: 1.2234 - accuracy: 0.5692 - val_loss: 1.8080 - val_accuracy: 0.4003
# Epoch 5/50
# 184/184 [==============================] - 47s 251ms/step - loss: 0.7879 - accuracy: 0.7334 - val_loss: 1.9098 - val_accuracy: 0.4472
# Epoch 6/50
# 184/184 [==============================] - 46s 251ms/step - loss: 0.4599 - accuracy: 0.8518 - val_loss: 2.3612 - val_accuracy: 0.4261
# Epoch 7/50
# 184/184 [==============================] - 46s 250ms/step - loss: 0.2672 - accuracy: 0.9156 - val_loss: 2.8938 - val_accuracy: 0.4554
# Epoch 8/50
# 184/184 [==============================] - 46s 250ms/step - loss: 0.1527 - accuracy: 0.9529 - val_loss: 3.0514 - val_accuracy: 0.4922
# Epoch 9/50
# 184/184 [==============================] - 46s 250ms/step - loss: 0.1513 - accuracy: 0.9560 - val_loss: 3.4865 - val_accuracy: 0.4888
# Epoch 10/50
# 184/184 [==============================] - 46s 249ms/step - loss: 0.1390 - accuracy: 0.9599 - val_loss: 3.7774 - val_accuracy: 0.4894
# Epoch 11/50
# 184/184 [==============================] - 45s 244ms/step - loss: 0.1269 - accuracy: 0.9628 - val_loss: 3.6521 - val_accuracy: 0.4956
# Epoch 12/50
# 184/184 [==============================] - 47s 254ms/step - loss: 0.0842 - accuracy: 0.9790 - val_loss: 4.3645 - val_accuracy: 0.4908
# Epoch 13/50
# 184/184 [==============================] - 47s 252ms/step - loss: 0.0788 - accuracy: 0.9789 - val_loss: 4.2040 - val_accuracy: 0.4758
# Epoch 14/50
# 184/184 [==============================] - 45s 246ms/step - loss: 0.0650 - accuracy: 0.9792 - val_loss: 4.1431 - val_accuracy: 0.5003
# Epoch 15/50
# 184/184 [==============================] - 47s 253ms/step - loss: 0.0251 - accuracy: 0.9942 - val_loss: 4.4326 - val_accuracy: 0.5071
# Epoch 16/50
# 184/184 [==============================] - 47s 253ms/step - loss: 0.0379 - accuracy: 0.9898 - val_loss: 4.3532 - val_accuracy: 0.4881
# Epoch 17/50
# 184/184 [==============================] - 47s 252ms/step - loss: 0.0517 - accuracy: 0.9840 - val_loss: 4.9411 - val_accuracy: 0.4894
# Epoch 18/50
# 184/184 [==============================] - 47s 253ms/step - loss: 0.1087 - accuracy: 0.9684 - val_loss: 4.6232 - val_accuracy: 0.4411
# Epoch 19/50
# 184/184 [==============================] - 47s 253ms/step - loss: 0.1181 - accuracy: 0.9683 - val_loss: 5.1280 - val_accuracy: 0.4888
# Epoch 20/50
# 184/184 [==============================] - 50s 268ms/step - loss: 0.0917 - accuracy: 0.9748 - val_loss: 5.8752 - val_accuracy: 0.4929
# Epoch 21/50
# 184/184 [==============================] - 50s 270ms/step - loss: 0.0799 - accuracy: 0.9824 - val_loss: 4.8027 - val_accuracy: 0.5119
# Epoch 22/50
# 184/184 [==============================] - 50s 268ms/step - loss: 0.0359 - accuracy: 0.9901 - val_loss: 5.9396 - val_accuracy: 0.5262
# Epoch 23/50
# 184/184 [==============================] - 49s 267ms/step - loss: 0.0377 - accuracy: 0.9891 - val_loss: 5.8429 - val_accuracy: 0.5126
# Epoch 24/50
# 184/184 [==============================] - 50s 268ms/step - loss: 0.0717 - accuracy: 0.9783 - val_loss: 6.5570 - val_accuracy: 0.5044
# Epoch 25/50
# 184/184 [==============================] - 47s 255ms/step - loss: 0.0336 - accuracy: 0.9899 - val_loss: 6.1220 - val_accuracy: 0.4976
# Epoch 26/50
# 184/184 [==============================] - 47s 256ms/step - loss: 0.0667 - accuracy: 0.9840 - val_loss: 5.3584 - val_accuracy: 0.4799
# Epoch 27/50
# 184/184 [==============================] - 48s 260ms/step - loss: 0.0894 - accuracy: 0.9770 - val_loss: 4.9063 - val_accuracy: 0.4963
# Epoch 28/50
# 184/184 [==============================] - 49s 268ms/step - loss: 0.0499 - accuracy: 0.9886 - val_loss: 5.4611 - val_accuracy: 0.4929
# Epoch 29/50
# 184/184 [==============================] - 47s 253ms/step - loss: 0.0397 - accuracy: 0.9879 - val_loss: 5.6124 - val_accuracy: 0.5024
# Epoch 30/50
# 184/184 [==============================] - 46s 246ms/step - loss: 0.0229 - accuracy: 0.9949 - val_loss: 6.0089 - val_accuracy: 0.5092
# Epoch 31/50
# 184/184 [==============================] - 47s 254ms/step - loss: 0.0234 - accuracy: 0.9925 - val_loss: 6.4944 - val_accuracy: 0.5160
# Epoch 32/50
# 184/184 [==============================] - 47s 254ms/step - loss: 0.0130 - accuracy: 0.9962 - val_loss: 6.9981 - val_accuracy: 0.4956
# Epoch 33/50
#  89/184 [=============>................] - ETA: 19s - loss: 0.0616 - accuracy: 0.9842

# %%
# Plot accuracy and loss curves
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
# Evaluate model
test_data = r'D:\Project\data_kaggle\test'

eval_generator = train_datagen.flow_from_directory(
    test_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

y_true = eval_generator.classes
y_pred = model.predict(eval_generator)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)  # Fix tf.argmax issue

# %%
# Print classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred_classes))

# Plot confusion matrix
conf_mat = confusion_matrix(y_true, y_pred_classes)
class_labels = list(train_generator.class_indices.keys())

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="viridis", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('Actual', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)
plt.show()

# %%
model_version = epochs
next_version = str(int(model_version) + 10)

# %%
import shutil

notebook_filename = f"CNN_{model_version}_ADAM.ipynb"
new_notebook_filename = f"CNN_{next_version}_ADAM.ipynb"

shutil.copy(notebook_filename, new_notebook_filename)
print(f"Notebook copied as {new_notebook_filename}")

# %%
os._exit(00)
