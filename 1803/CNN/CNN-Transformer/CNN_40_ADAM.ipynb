# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Flatten, Dense, LayerNormalization, MultiHeadAttention, Add, Reshape, GlobalAveragePooling2D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Input
import os

# %%
# Set dataset path
data_dir = r'D:\Project\data_kaggle\aug\train_split'

# %%
batch_size = 32
img_height = 224
img_width = 224
image_size = (img_height, img_width)
epochs = int(input("Enter epochs number: "))
# Out:
# Enter epochs number:  40

# %%
train_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb'  # Force RGB mode
)
# Out:
# Found 5863 images belonging to 8 classes.

# %%
val_datagen = ImageDataGenerator()

val_data = r"D:\Project\data_kaggle\aug\val_split"

val_generator = val_datagen.flow_from_directory(
    val_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
)
# Out:
# Found 1469 images belonging to 8 classes.

# %%
def create_cnn_base(input_shape):
    inputs = Input(shape=input_shape)

    # First Conv Block
    x = Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(inputs)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)

    # Second Conv Block
    x = Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.4)(x)

    # Third Conv Block
    x = Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.5)(x)

    return inputs, x

def transformer_encoder(inputs, num_heads, key_dim, ff_dim, dropout_rate=0.1):
    # Layer Normalization and Multi-Head Attention
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim, dropout=dropout_rate)(x, x)
    x = Dropout(dropout_rate)(x)
    x = Add()([x, inputs])

    # Feed Forward Network
    y = LayerNormalization(epsilon=1e-6)(x)
    y = Dense(ff_dim, activation='relu')(y)
    y = Dropout(dropout_rate)(y)
    y = Dense(inputs.shape[-1])(y)
    outputs = Add()([y, x])

    return outputs

def create_hybrid_model(input_shape, num_classes, num_transformer_blocks=1, num_heads=4, key_dim=128, ff_dim=256, dropout_rate=0.1):
    inputs, cnn_output = create_cnn_base(input_shape)

    # Reshape CNN output for Transformer
    x = Reshape((-1, cnn_output.shape[-1]))(cnn_output)

    # Apply Transformer blocks
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, num_heads, key_dim, ff_dim, dropout_rate)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(cnn_output)

    # Fully Connected Layer
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

input_shape = (224, 224, 3)
num_classes = len(train_generator.class_indices)

model = create_hybrid_model(input_shape, num_classes)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 128,328
# Trainable params: 128,328
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)
# Out:
# Epoch 1/40
# 184/184 [==============================] - 24s 96ms/step - loss: 2.8563 - accuracy: 0.2823 - val_loss: 2.0703 - val_accuracy: 0.3751
# Epoch 2/40
# 184/184 [==============================] - 17s 89ms/step - loss: 1.8918 - accuracy: 0.4092 - val_loss: 1.8722 - val_accuracy: 0.4479
# Epoch 3/40
# 184/184 [==============================] - 16s 84ms/step - loss: 1.7579 - accuracy: 0.4518 - val_loss: 1.8787 - val_accuracy: 0.3962
# Epoch 4/40
# 184/184 [==============================] - 17s 90ms/step - loss: 1.6366 - accuracy: 0.4989 - val_loss: 1.5214 - val_accuracy: 0.5575
# Epoch 5/40
# 184/184 [==============================] - 17s 94ms/step - loss: 1.5200 - accuracy: 0.5374 - val_loss: 1.4884 - val_accuracy: 0.5916
# Epoch 6/40
# 184/184 [==============================] - 16s 85ms/step - loss: 1.4298 - accuracy: 0.5719 - val_loss: 1.4087 - val_accuracy: 0.5997
# Epoch 7/40
# 184/184 [==============================] - 16s 88ms/step - loss: 1.3279 - accuracy: 0.5971 - val_loss: 1.2845 - val_accuracy: 0.6399
# Epoch 8/40
# 184/184 [==============================] - 16s 89ms/step - loss: 1.2645 - accuracy: 0.6231 - val_loss: 1.2499 - val_accuracy: 0.6787
# Epoch 9/40
# 184/184 [==============================] - 16s 88ms/step - loss: 1.2384 - accuracy: 0.6338 - val_loss: 1.1694 - val_accuracy: 0.6644
# Epoch 10/40
# 184/184 [==============================] - 17s 90ms/step - loss: 1.1663 - accuracy: 0.6568 - val_loss: 1.1289 - val_accuracy: 0.6773
# Epoch 11/40
# 184/184 [==============================] - 17s 91ms/step - loss: 1.1353 - accuracy: 0.6683 - val_loss: 1.1855 - val_accuracy: 0.6426
# Epoch 12/40
# 184/184 [==============================] - 16s 87ms/step - loss: 1.0868 - accuracy: 0.6754 - val_loss: 0.9953 - val_accuracy: 0.7366
# Epoch 13/40
# 184/184 [==============================] - 16s 87ms/step - loss: 1.0828 - accuracy: 0.6783 - val_loss: 1.0246 - val_accuracy: 0.6964
# Epoch 14/40
# 184/184 [==============================] - 16s 88ms/step - loss: 1.0267 - accuracy: 0.6945 - val_loss: 1.0053 - val_accuracy: 0.7427
# Epoch 15/40
# 184/184 [==============================] - 18s 99ms/step - loss: 0.9884 - accuracy: 0.7109 - val_loss: 1.0132 - val_accuracy: 0.7216
# Epoch 16/40
# 184/184 [==============================] - 17s 92ms/step - loss: 0.9763 - accuracy: 0.7155 - val_loss: 0.9883 - val_accuracy: 0.7686
# Epoch 17/40
# 184/184 [==============================] - 18s 96ms/step - loss: 0.9677 - accuracy: 0.7227 - val_loss: 0.9241 - val_accuracy: 0.7856
# Epoch 18/40
# 184/184 [==============================] - 17s 94ms/step - loss: 0.9050 - accuracy: 0.7394 - val_loss: 0.8687 - val_accuracy: 0.7692
# Epoch 19/40
# 184/184 [==============================] - 17s 93ms/step - loss: 0.8918 - accuracy: 0.7433 - val_loss: 0.8553 - val_accuracy: 0.8108
# Epoch 20/40
# 184/184 [==============================] - 17s 91ms/step - loss: 0.8695 - accuracy: 0.7489 - val_loss: 0.7589 - val_accuracy: 0.8182
# Epoch 21/40
# 184/184 [==============================] - 17s 90ms/step - loss: 0.8348 - accuracy: 0.7670 - val_loss: 0.9391 - val_accuracy: 0.7393
# Epoch 22/40
# 184/184 [==============================] - 16s 88ms/step - loss: 0.8315 - accuracy: 0.7679 - val_loss: 0.8311 - val_accuracy: 0.7733
# Epoch 23/40
# 184/184 [==============================] - 16s 87ms/step - loss: 0.8148 - accuracy: 0.7737 - val_loss: 0.7951 - val_accuracy: 0.7971
# Epoch 24/40
# 184/184 [==============================] - 17s 89ms/step - loss: 0.7870 - accuracy: 0.7825 - val_loss: 0.8121 - val_accuracy: 0.7808
# Epoch 25/40
# 184/184 [==============================] - 17s 91ms/step - loss: 0.8042 - accuracy: 0.7819 - val_loss: 0.6906 - val_accuracy: 0.8373
# Epoch 26/40
# 184/184 [==============================] - 16s 87ms/step - loss: 0.7520 - accuracy: 0.7904 - val_loss: 0.7035 - val_accuracy: 0.8278
# Epoch 27/40
# 184/184 [==============================] - 17s 90ms/step - loss: 0.7441 - accuracy: 0.8042 - val_loss: 0.7069 - val_accuracy: 0.8257
# Epoch 28/40
# 184/184 [==============================] - 16s 89ms/step - loss: 0.7486 - accuracy: 0.7938 - val_loss: 0.6511 - val_accuracy: 0.8387
# Epoch 29/40
# 184/184 [==============================] - 16s 87ms/step - loss: 0.7294 - accuracy: 0.7970 - val_loss: 0.6885 - val_accuracy: 0.8264
# Epoch 30/40
# 184/184 [==============================] - 16s 88ms/step - loss: 0.7020 - accuracy: 0.8155 - val_loss: 0.5747 - val_accuracy: 0.8713
# Epoch 31/40
# 184/184 [==============================] - 16s 87ms/step - loss: 0.6793 - accuracy: 0.8272 - val_loss: 0.6672 - val_accuracy: 0.8291
# Epoch 32/40
# 184/184 [==============================] - 16s 88ms/step - loss: 0.6625 - accuracy: 0.8310 - val_loss: 0.9344 - val_accuracy: 0.7386
# Epoch 33/40
# 184/184 [==============================] - 16s 87ms/step - loss: 0.6761 - accuracy: 0.8189 - val_loss: 0.5645 - val_accuracy: 0.8700
# Epoch 34/40
# 184/184 [==============================] - 16s 87ms/step - loss: 0.6287 - accuracy: 0.8388 - val_loss: 0.5805 - val_accuracy: 0.8761
# Epoch 35/40
# 184/184 [==============================] - 16s 88ms/step - loss: 0.6248 - accuracy: 0.8380 - val_loss: 0.6408 - val_accuracy: 0.8359
# Epoch 36/40
# 184/184 [==============================] - 16s 88ms/step - loss: 0.6364 - accuracy: 0.8412 - val_loss: 0.5331 - val_accuracy: 0.8802
# Epoch 37/40
# 184/184 [==============================] - 16s 88ms/step - loss: 0.6716 - accuracy: 0.8255 - val_loss: 0.6337 - val_accuracy: 0.8482
# Epoch 38/40
# 184/184 [==============================] - 16s 87ms/step - loss: 0.6090 - accuracy: 0.8492 - val_loss: 0.6226 - val_accuracy: 0.8496
# Epoch 39/40
# 184/184 [==============================] - 16s 87ms/step - loss: 0.6156 - accuracy: 0.8496 - val_loss: 0.5411 - val_accuracy: 0.8999
# Epoch 40/40
# 184/184 [==============================] - 16s 87ms/step - loss: 0.5914 - accuracy: 0.8518 - val_loss: 0.5752 - val_accuracy: 0.8645

# %%
# Plot accuracy and loss curves
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
# Evaluate model
test_data = r'D:\Project\data_kaggle\test'

eval_generator = train_datagen.flow_from_directory(
    test_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

y_true = eval_generator.classes
y_pred = model.predict(eval_generator)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)  # Fix tf.argmax issue
# Out:
# Found 190 images belonging to 8 classes.

# %%
# Print classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred_classes))

# Plot confusion matrix
conf_mat = confusion_matrix(y_true, y_pred_classes)
class_labels = list(train_generator.class_indices.keys())
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97        28
#            1       0.72      0.62      0.67        21
#            2       0.95      0.80      0.87        25
#            3       0.82      0.78      0.80        23
#            4       0.50      0.90      0.64        21
#            5       0.83      0.43      0.57        23
#            6       0.89      0.92      0.91        26
#            7       0.91      0.87      0.89        23
#
#     accuracy                           0.80       190
#    macro avg       0.82      0.79      0.79       190
# weighted avg       0.83      0.80      0.80       190

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="viridis", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('Actual', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)
plt.show()

# %%
model_version = epochs
next_version = str(int(model_version) + 10)

# %%
import shutil

notebook_filename = f"CNN_{model_version}_ADAM.ipynb"
new_notebook_filename = f"CNN_{next_version}_ADAM.ipynb"

shutil.copy(notebook_filename, new_notebook_filename)
print(f"Notebook copied as {new_notebook_filename}")
# Out:
# Notebook copied as CNN_50_ADAM.ipynb

# %%
os._exit(00)
