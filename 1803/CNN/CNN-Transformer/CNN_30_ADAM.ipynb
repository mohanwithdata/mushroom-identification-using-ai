# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Flatten, Dense, LayerNormalization, MultiHeadAttention, Add, Reshape, GlobalAveragePooling2D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Input
import os

# %%
# Set dataset path
data_dir = r'D:\Project\data_kaggle\aug\train_split'

# %%
batch_size = 32
img_height = 224
img_width = 224
image_size = (img_height, img_width)
epochs = int(input("Enter epochs number: "))
# Out:
# Enter epochs number:  30

# %%
train_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb'  # Force RGB mode
)
# Out:
# Found 5863 images belonging to 8 classes.

# %%
val_datagen = ImageDataGenerator()

val_data = r"D:\Project\data_kaggle\aug\val_split"

val_generator = val_datagen.flow_from_directory(
    val_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
)
# Out:
# Found 1469 images belonging to 8 classes.

# %%
def create_cnn_base(input_shape):
    inputs = Input(shape=input_shape)

    # First Conv Block
    x = Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(inputs)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)

    # Second Conv Block
    x = Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.4)(x)

    # Third Conv Block
    x = Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.5)(x)

    return inputs, x

def transformer_encoder(inputs, num_heads, key_dim, ff_dim, dropout_rate=0.1):
    # Layer Normalization and Multi-Head Attention
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim, dropout=dropout_rate)(x, x)
    x = Dropout(dropout_rate)(x)
    x = Add()([x, inputs])

    # Feed Forward Network
    y = LayerNormalization(epsilon=1e-6)(x)
    y = Dense(ff_dim, activation='relu')(y)
    y = Dropout(dropout_rate)(y)
    y = Dense(inputs.shape[-1])(y)
    outputs = Add()([y, x])

    return outputs

def create_hybrid_model(input_shape, num_classes, num_transformer_blocks=1, num_heads=4, key_dim=128, ff_dim=256, dropout_rate=0.1):
    inputs, cnn_output = create_cnn_base(input_shape)

    # Reshape CNN output for Transformer
    x = Reshape((-1, cnn_output.shape[-1]))(cnn_output)

    # Apply Transformer blocks
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, num_heads, key_dim, ff_dim, dropout_rate)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(cnn_output)

    # Fully Connected Layer
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

input_shape = (224, 224, 3)
num_classes = len(train_generator.class_indices)

model = create_hybrid_model(input_shape, num_classes)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 128,328
# Trainable params: 128,328
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)
# Out:
# Epoch 1/30
# 184/184 [==============================] - 22s 92ms/step - loss: 2.8244 - accuracy: 0.2391 - val_loss: 2.0218 - val_accuracy: 0.3833
# Epoch 2/30
# 184/184 [==============================] - 17s 90ms/step - loss: 1.9203 - accuracy: 0.3831 - val_loss: 1.8827 - val_accuracy: 0.4350
# Epoch 3/30
# 184/184 [==============================] - 16s 86ms/step - loss: 1.7910 - accuracy: 0.4208 - val_loss: 1.7861 - val_accuracy: 0.4193
# Epoch 4/30
# 184/184 [==============================] - 16s 86ms/step - loss: 1.6989 - accuracy: 0.4592 - val_loss: 1.6557 - val_accuracy: 0.4826
# Epoch 5/30
# 184/184 [==============================] - 17s 90ms/step - loss: 1.6040 - accuracy: 0.4962 - val_loss: 1.5562 - val_accuracy: 0.5296
# Epoch 6/30
# 184/184 [==============================] - 17s 92ms/step - loss: 1.5023 - accuracy: 0.5322 - val_loss: 1.4657 - val_accuracy: 0.5854
# Epoch 7/30
# 184/184 [==============================] - 17s 94ms/step - loss: 1.4239 - accuracy: 0.5586 - val_loss: 1.3250 - val_accuracy: 0.6426
# Epoch 8/30
# 184/184 [==============================] - 18s 96ms/step - loss: 1.3280 - accuracy: 0.5959 - val_loss: 1.2743 - val_accuracy: 0.6372
# Epoch 9/30
# 184/184 [==============================] - 16s 88ms/step - loss: 1.2854 - accuracy: 0.6094 - val_loss: 1.2270 - val_accuracy: 0.6236
# Epoch 10/30
# 184/184 [==============================] - 16s 88ms/step - loss: 1.2068 - accuracy: 0.6343 - val_loss: 1.1864 - val_accuracy: 0.6542
# Epoch 11/30
# 184/184 [==============================] - 16s 86ms/step - loss: 1.1754 - accuracy: 0.6393 - val_loss: 1.1685 - val_accuracy: 0.6705
# Epoch 12/30
# 184/184 [==============================] - 16s 86ms/step - loss: 1.1723 - accuracy: 0.6452 - val_loss: 1.1552 - val_accuracy: 0.6440
# Epoch 13/30
# 184/184 [==============================] - 16s 89ms/step - loss: 1.1130 - accuracy: 0.6676 - val_loss: 1.0373 - val_accuracy: 0.7093
# Epoch 14/30
# 184/184 [==============================] - 16s 87ms/step - loss: 1.0642 - accuracy: 0.6826 - val_loss: 1.0558 - val_accuracy: 0.6753
# Epoch 15/30
# 184/184 [==============================] - 16s 87ms/step - loss: 1.0263 - accuracy: 0.6949 - val_loss: 1.0792 - val_accuracy: 0.6658
# Epoch 16/30
# 184/184 [==============================] - 16s 86ms/step - loss: 0.9920 - accuracy: 0.7102 - val_loss: 0.9320 - val_accuracy: 0.7461
# Epoch 17/30
# 184/184 [==============================] - 16s 87ms/step - loss: 0.9859 - accuracy: 0.7099 - val_loss: 0.9121 - val_accuracy: 0.7495
# Epoch 18/30
# 184/184 [==============================] - 16s 88ms/step - loss: 0.9475 - accuracy: 0.7268 - val_loss: 0.9219 - val_accuracy: 0.7767
# Epoch 19/30
# 184/184 [==============================] - 16s 87ms/step - loss: 0.9380 - accuracy: 0.7278 - val_loss: 0.9204 - val_accuracy: 0.7277
# Epoch 20/30
# 184/184 [==============================] - 16s 86ms/step - loss: 0.8778 - accuracy: 0.7459 - val_loss: 1.0286 - val_accuracy: 0.6787
# Epoch 21/30
# 184/184 [==============================] - 16s 87ms/step - loss: 0.8930 - accuracy: 0.7404 - val_loss: 0.8294 - val_accuracy: 0.7815
# Epoch 22/30
# 184/184 [==============================] - 16s 87ms/step - loss: 0.8495 - accuracy: 0.7559 - val_loss: 0.8293 - val_accuracy: 0.7937
# Epoch 23/30
# 184/184 [==============================] - 16s 88ms/step - loss: 0.8503 - accuracy: 0.7561 - val_loss: 0.7375 - val_accuracy: 0.8080
# Epoch 24/30
# 184/184 [==============================] - 16s 87ms/step - loss: 0.8365 - accuracy: 0.7641 - val_loss: 0.7196 - val_accuracy: 0.8128
# Epoch 25/30
# 184/184 [==============================] - 16s 88ms/step - loss: 0.8017 - accuracy: 0.7757 - val_loss: 0.7543 - val_accuracy: 0.8216
# Epoch 26/30
# 184/184 [==============================] - 16s 86ms/step - loss: 0.7596 - accuracy: 0.7938 - val_loss: 0.7530 - val_accuracy: 0.7897
# Epoch 27/30
# 184/184 [==============================] - 16s 86ms/step - loss: 0.7257 - accuracy: 0.8052 - val_loss: 0.8077 - val_accuracy: 0.7754
# Epoch 28/30
# 184/184 [==============================] - 17s 92ms/step - loss: 0.7740 - accuracy: 0.7900 - val_loss: 0.9063 - val_accuracy: 0.7189
# Epoch 29/30
# 184/184 [==============================] - 17s 91ms/step - loss: 0.7172 - accuracy: 0.8030 - val_loss: 0.6917 - val_accuracy: 0.8251
# Epoch 30/30
# 184/184 [==============================] - 16s 88ms/step - loss: 0.7056 - accuracy: 0.8126 - val_loss: 0.6799 - val_accuracy: 0.8244

# %%
# Plot accuracy and loss curves
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
# Evaluate model
test_data = r'D:\Project\data_kaggle\test'

eval_generator = train_datagen.flow_from_directory(
    test_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

y_true = eval_generator.classes
y_pred = model.predict(eval_generator)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)  # Fix tf.argmax issue
# Out:
# Found 190 images belonging to 8 classes.

# %%
# Print classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred_classes))

# Plot confusion matrix
conf_mat = confusion_matrix(y_true, y_pred_classes)
class_labels = list(train_generator.class_indices.keys())
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95        28
#            1       0.39      0.52      0.45        21
#            2       0.87      0.80      0.83        25
#            3       1.00      0.65      0.79        23
#            4       0.47      0.76      0.58        21
#            5       0.75      0.39      0.51        23
#            6       0.76      0.85      0.80        26
#            7       0.94      0.74      0.83        23
#
#     accuracy                           0.73       190
#    macro avg       0.76      0.71      0.72       190
# weighted avg       0.77      0.73      0.73       190

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="viridis", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('Actual', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)
plt.show()

# %%
model_version = epochs
next_version = str(int(model_version) + 10)

# %%
import shutil

notebook_filename = f"CNN_{model_version}_ADAM.ipynb"
new_notebook_filename = f"CNN_{next_version}_ADAM.ipynb"

shutil.copy(notebook_filename, new_notebook_filename)
print(f"Notebook copied as {new_notebook_filename}")
# Out:
# Notebook copied as CNN_40_ADAM.ipynb

# %%
os._exit(00)
