# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Flatten, Dense, LayerNormalization, MultiHeadAttention, Add, Reshape, GlobalAveragePooling2D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Input
import os

# %%
# Set dataset path
data_dir = r'D:\Project\data_kaggle\aug\train_split'

# %%
batch_size = 32
img_height = 224
img_width = 224
image_size = (img_height, img_width)
epochs = int(input("Enter epochs number: "))
# Out:
# Enter epochs number:  70

# %%
train_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb'  # Force RGB mode
)
# Out:
# Found 5863 images belonging to 8 classes.

# %%
val_datagen = ImageDataGenerator()

val_data = r"D:\Project\data_kaggle\aug\val_split"

val_generator = val_datagen.flow_from_directory(
    val_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
)
# Out:
# Found 1469 images belonging to 8 classes.

# %%
def create_cnn_base(input_shape):
    inputs = Input(shape=input_shape)

    # First Conv Block
    x = Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(inputs)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)

    # Second Conv Block
    x = Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.4)(x)

    # Third Conv Block
    x = Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.5)(x)

    return inputs, x

def transformer_encoder(inputs, num_heads, key_dim, ff_dim, dropout_rate=0.1):
    # Layer Normalization and Multi-Head Attention
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim, dropout=dropout_rate)(x, x)
    x = Dropout(dropout_rate)(x)
    x = Add()([x, inputs])

    # Feed Forward Network
    y = LayerNormalization(epsilon=1e-6)(x)
    y = Dense(ff_dim, activation='relu')(y)
    y = Dropout(dropout_rate)(y)
    y = Dense(inputs.shape[-1])(y)
    outputs = Add()([y, x])

    return outputs

def create_hybrid_model(input_shape, num_classes, num_transformer_blocks=1, num_heads=4, key_dim=128, ff_dim=256, dropout_rate=0.1):
    inputs, cnn_output = create_cnn_base(input_shape)

    # Reshape CNN output for Transformer
    x = Reshape((-1, cnn_output.shape[-1]))(cnn_output)

    # Apply Transformer blocks
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, num_heads, key_dim, ff_dim, dropout_rate)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(cnn_output)

    # Fully Connected Layer
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

input_shape = (224, 224, 3)
num_classes = len(train_generator.class_indices)

model = create_hybrid_model(input_shape, num_classes)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 128,328
# Trainable params: 128,328
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)
# Out:
# Epoch 1/70
# 184/184 [==============================] - 21s 87ms/step - loss: 3.3709 - accuracy: 0.2482 - val_loss: 2.1804 - val_accuracy: 0.3642
# Epoch 2/70
# 184/184 [==============================] - 15s 81ms/step - loss: 1.9823 - accuracy: 0.3580 - val_loss: 2.0335 - val_accuracy: 0.3792
# Epoch 3/70
# 184/184 [==============================] - 15s 82ms/step - loss: 1.8567 - accuracy: 0.4146 - val_loss: 1.9019 - val_accuracy: 0.4595
# Epoch 4/70
# 184/184 [==============================] - 16s 85ms/step - loss: 1.7237 - accuracy: 0.4641 - val_loss: 1.7402 - val_accuracy: 0.5344
# Epoch 5/70
# 184/184 [==============================] - 15s 82ms/step - loss: 1.6650 - accuracy: 0.4839 - val_loss: 1.6054 - val_accuracy: 0.5242
# Epoch 6/70
# 184/184 [==============================] - 15s 82ms/step - loss: 1.5252 - accuracy: 0.5298 - val_loss: 1.5523 - val_accuracy: 0.5085
# Epoch 7/70
# 184/184 [==============================] - 16s 84ms/step - loss: 1.4331 - accuracy: 0.5668 - val_loss: 1.4150 - val_accuracy: 0.6229
# Epoch 8/70
# 184/184 [==============================] - 15s 83ms/step - loss: 1.3363 - accuracy: 0.6029 - val_loss: 1.3626 - val_accuracy: 0.6181
# Epoch 9/70
# 184/184 [==============================] - 15s 82ms/step - loss: 1.3027 - accuracy: 0.6036 - val_loss: 1.3942 - val_accuracy: 0.5977
# Epoch 10/70
# 184/184 [==============================] - 15s 82ms/step - loss: 1.2420 - accuracy: 0.6324 - val_loss: 1.2720 - val_accuracy: 0.6133
# Epoch 11/70
# 184/184 [==============================] - 15s 82ms/step - loss: 1.2016 - accuracy: 0.6463 - val_loss: 1.1942 - val_accuracy: 0.6447
# Epoch 12/70
# 184/184 [==============================] - 15s 82ms/step - loss: 1.1780 - accuracy: 0.6585 - val_loss: 1.1528 - val_accuracy: 0.6406
# Epoch 13/70
# 184/184 [==============================] - 15s 83ms/step - loss: 1.1449 - accuracy: 0.6674 - val_loss: 1.0473 - val_accuracy: 0.7195
# Epoch 14/70
# 184/184 [==============================] - 15s 84ms/step - loss: 1.1034 - accuracy: 0.6850 - val_loss: 0.9852 - val_accuracy: 0.7461
# Epoch 15/70
# 184/184 [==============================] - 15s 84ms/step - loss: 1.0586 - accuracy: 0.6886 - val_loss: 1.1872 - val_accuracy: 0.6664
# Epoch 16/70
# 184/184 [==============================] - 16s 85ms/step - loss: 1.0363 - accuracy: 0.7015 - val_loss: 0.9793 - val_accuracy: 0.7325
# Epoch 17/70
# 184/184 [==============================] - 15s 83ms/step - loss: 1.0083 - accuracy: 0.7123 - val_loss: 1.0054 - val_accuracy: 0.7277
# Epoch 18/70
# 184/184 [==============================] - 15s 83ms/step - loss: 0.9650 - accuracy: 0.7208 - val_loss: 0.9127 - val_accuracy: 0.7822
# Epoch 19/70
# 184/184 [==============================] - 16s 85ms/step - loss: 0.9253 - accuracy: 0.7348 - val_loss: 0.8901 - val_accuracy: 0.7665
# Epoch 20/70
# 184/184 [==============================] - 15s 83ms/step - loss: 0.8991 - accuracy: 0.7418 - val_loss: 0.8368 - val_accuracy: 0.7869
# Epoch 21/70
# 184/184 [==============================] - 15s 82ms/step - loss: 0.8904 - accuracy: 0.7479 - val_loss: 0.9751 - val_accuracy: 0.7100
# Epoch 22/70
# 184/184 [==============================] - 15s 83ms/step - loss: 0.8966 - accuracy: 0.7508 - val_loss: 0.7981 - val_accuracy: 0.8094
# Epoch 23/70
# 184/184 [==============================] - 16s 84ms/step - loss: 0.8255 - accuracy: 0.7764 - val_loss: 0.8029 - val_accuracy: 0.7767
# Epoch 24/70
# 184/184 [==============================] - 15s 83ms/step - loss: 0.8163 - accuracy: 0.7713 - val_loss: 0.7261 - val_accuracy: 0.8189
# Epoch 25/70
# 184/184 [==============================] - 15s 82ms/step - loss: 0.8428 - accuracy: 0.7662 - val_loss: 0.6817 - val_accuracy: 0.8312
# Epoch 26/70
# 184/184 [==============================] - 15s 82ms/step - loss: 0.7997 - accuracy: 0.7839 - val_loss: 0.8226 - val_accuracy: 0.7590
# Epoch 27/70
# 184/184 [==============================] - 15s 83ms/step - loss: 0.7835 - accuracy: 0.7839 - val_loss: 0.8389 - val_accuracy: 0.7740
# Epoch 28/70
# 184/184 [==============================] - 15s 83ms/step - loss: 0.7396 - accuracy: 0.8037 - val_loss: 0.6796 - val_accuracy: 0.8346
# Epoch 29/70
# 184/184 [==============================] - 15s 83ms/step - loss: 0.7433 - accuracy: 0.8062 - val_loss: 0.7485 - val_accuracy: 0.8108
# Epoch 30/70
# 184/184 [==============================] - 15s 83ms/step - loss: 0.7146 - accuracy: 0.8102 - val_loss: 0.7341 - val_accuracy: 0.8101
# Epoch 31/70
# 184/184 [==============================] - 16s 84ms/step - loss: 0.7184 - accuracy: 0.8119 - val_loss: 0.7513 - val_accuracy: 0.8189
# Epoch 32/70
# 184/184 [==============================] - 15s 83ms/step - loss: 0.7088 - accuracy: 0.8146 - val_loss: 0.6936 - val_accuracy: 0.8216
# Epoch 33/70
# 184/184 [==============================] - 15s 82ms/step - loss: 0.6910 - accuracy: 0.8214 - val_loss: 0.6700 - val_accuracy: 0.8332
# Epoch 34/70
# 184/184 [==============================] - 15s 82ms/step - loss: 0.6827 - accuracy: 0.8267 - val_loss: 0.6673 - val_accuracy: 0.8203
# Epoch 35/70
# 184/184 [==============================] - 15s 82ms/step - loss: 0.6724 - accuracy: 0.8267 - val_loss: 0.7050 - val_accuracy: 0.8244
# Epoch 36/70
# 184/184 [==============================] - 15s 82ms/step - loss: 0.6546 - accuracy: 0.8313 - val_loss: 0.7044 - val_accuracy: 0.8162
# Epoch 37/70
# 184/184 [==============================] - 15s 83ms/step - loss: 0.6482 - accuracy: 0.8426 - val_loss: 0.5932 - val_accuracy: 0.8584
# Epoch 38/70
# 184/184 [==============================] - 15s 83ms/step - loss: 0.6357 - accuracy: 0.8412 - val_loss: 0.6038 - val_accuracy: 0.8618
# Epoch 39/70
# 184/184 [==============================] - 16s 84ms/step - loss: 0.6875 - accuracy: 0.8262 - val_loss: 0.7202 - val_accuracy: 0.8067
# Epoch 40/70
# 184/184 [==============================] - 15s 82ms/step - loss: 0.6321 - accuracy: 0.8405 - val_loss: 0.5677 - val_accuracy: 0.8754
# Epoch 41/70
# 184/184 [==============================] - 15s 82ms/step - loss: 0.6374 - accuracy: 0.8392 - val_loss: 0.5825 - val_accuracy: 0.8679
# Epoch 42/70
# 184/184 [==============================] - 15s 82ms/step - loss: 0.5983 - accuracy: 0.8554 - val_loss: 0.5532 - val_accuracy: 0.8727
# Epoch 43/70
# 184/184 [==============================] - 15s 82ms/step - loss: 0.6086 - accuracy: 0.8511 - val_loss: 0.5743 - val_accuracy: 0.8693
# Epoch 44/70
# 184/184 [==============================] - 15s 83ms/step - loss: 0.6032 - accuracy: 0.8571 - val_loss: 0.5282 - val_accuracy: 0.8958
# Epoch 45/70
# 184/184 [==============================] - 15s 83ms/step - loss: 0.5956 - accuracy: 0.8550 - val_loss: 0.5657 - val_accuracy: 0.8747
# Epoch 46/70
# 184/184 [==============================] - 15s 83ms/step - loss: 0.5804 - accuracy: 0.8632 - val_loss: 0.6558 - val_accuracy: 0.8393
# Epoch 47/70
# 184/184 [==============================] - 16s 84ms/step - loss: 0.6294 - accuracy: 0.8383 - val_loss: 0.7098 - val_accuracy: 0.8230
# Epoch 48/70
# 184/184 [==============================] - 15s 82ms/step - loss: 0.5661 - accuracy: 0.8673 - val_loss: 0.6262 - val_accuracy: 0.8421
# Epoch 49/70
# 184/184 [==============================] - 15s 82ms/step - loss: 0.5888 - accuracy: 0.8610 - val_loss: 0.5583 - val_accuracy: 0.8816
# Epoch 50/70
# 184/184 [==============================] - 15s 82ms/step - loss: 0.5744 - accuracy: 0.8694 - val_loss: 0.6267 - val_accuracy: 0.8414
# Epoch 51/70
# 184/184 [==============================] - 15s 82ms/step - loss: 0.5571 - accuracy: 0.8673 - val_loss: 0.6649 - val_accuracy: 0.8339
# Epoch 52/70
# 184/184 [==============================] - 15s 82ms/step - loss: 0.5962 - accuracy: 0.8566 - val_loss: 0.5339 - val_accuracy: 0.8795
# Epoch 53/70
# 184/184 [==============================] - 16s 84ms/step - loss: 0.5613 - accuracy: 0.8770 - val_loss: 0.5656 - val_accuracy: 0.8652
# Epoch 54/70
# 184/184 [==============================] - 17s 91ms/step - loss: 0.5507 - accuracy: 0.8740 - val_loss: 0.5481 - val_accuracy: 0.8734
# Epoch 55/70
# 184/184 [==============================] - 16s 86ms/step - loss: 0.5308 - accuracy: 0.8830 - val_loss: 0.5624 - val_accuracy: 0.8720
# Epoch 56/70
# 184/184 [==============================] - 16s 84ms/step - loss: 0.5352 - accuracy: 0.8762 - val_loss: 0.5710 - val_accuracy: 0.8700
# Epoch 57/70
# 184/184 [==============================] - 16s 84ms/step - loss: 0.5198 - accuracy: 0.8852 - val_loss: 0.5565 - val_accuracy: 0.8802
# Epoch 58/70
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5571 - accuracy: 0.8751 - val_loss: 0.5984 - val_accuracy: 0.8550
# Epoch 59/70
# 184/184 [==============================] - 17s 93ms/step - loss: 0.5103 - accuracy: 0.8869 - val_loss: 0.4869 - val_accuracy: 0.9027
# Epoch 60/70
# 184/184 [==============================] - 16s 86ms/step - loss: 0.5466 - accuracy: 0.8780 - val_loss: 0.5174 - val_accuracy: 0.8931
# Epoch 61/70
# 184/184 [==============================] - 17s 90ms/step - loss: 0.5206 - accuracy: 0.8856 - val_loss: 0.5464 - val_accuracy: 0.8822
# Epoch 62/70
# 184/184 [==============================] - 17s 90ms/step - loss: 0.5596 - accuracy: 0.8748 - val_loss: 0.5080 - val_accuracy: 0.8931
# Epoch 63/70
# 184/184 [==============================] - 17s 94ms/step - loss: 0.5220 - accuracy: 0.8881 - val_loss: 0.6084 - val_accuracy: 0.8543
# Epoch 64/70
# 184/184 [==============================] - 16s 85ms/step - loss: 0.4826 - accuracy: 0.9030 - val_loss: 0.4796 - val_accuracy: 0.9074
# Epoch 65/70
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5421 - accuracy: 0.8823 - val_loss: 0.7957 - val_accuracy: 0.8033
# Epoch 66/70
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5129 - accuracy: 0.8914 - val_loss: 0.5451 - val_accuracy: 0.8754
# Epoch 67/70
# 184/184 [==============================] - 16s 85ms/step - loss: 0.4744 - accuracy: 0.9001 - val_loss: 0.4728 - val_accuracy: 0.8986
# Epoch 68/70
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5091 - accuracy: 0.8896 - val_loss: 0.5468 - val_accuracy: 0.8897
# Epoch 69/70
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5001 - accuracy: 0.8958 - val_loss: 0.6273 - val_accuracy: 0.8278
# Epoch 70/70
# 184/184 [==============================] - 17s 93ms/step - loss: 0.5021 - accuracy: 0.8944 - val_loss: 0.5582 - val_accuracy: 0.8775

# %%
# Plot accuracy and loss curves
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
# Evaluate model
test_data = r'D:\Project\data_kaggle\test'

eval_generator = train_datagen.flow_from_directory(
    test_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

y_true = eval_generator.classes
y_pred = model.predict(eval_generator)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)  # Fix tf.argmax issue
# Out:
# Found 190 images belonging to 8 classes.

# %%
# Print classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred_classes))

# Plot confusion matrix
conf_mat = confusion_matrix(y_true, y_pred_classes)
class_labels = list(train_generator.class_indices.keys())
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        28
#            1       0.75      0.71      0.73        21
#            2       0.91      0.84      0.88        25
#            3       0.65      0.74      0.69        23
#            4       0.65      0.71      0.68        21
#            5       0.89      0.35      0.50        23
#            6       0.65      0.92      0.76        26
#            7       0.88      0.96      0.92        23
#
#     accuracy                           0.78       190
#    macro avg       0.80      0.77      0.77       190
# weighted avg       0.80      0.78      0.78       190

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="viridis", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('Actual', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)
plt.show()

# %%
model_version = epochs
next_version = str(int(model_version) + 10)

# %%
import shutil

notebook_filename = f"CNN_{model_version}_ADAM.ipynb"
new_notebook_filename = f"CNN_{next_version}_ADAM.ipynb"

shutil.copy(notebook_filename, new_notebook_filename)
print(f"Notebook copied as {new_notebook_filename}")
# Out:
# Notebook copied as CNN_80_ADAM.ipynb

# %%
os._exit(00)
