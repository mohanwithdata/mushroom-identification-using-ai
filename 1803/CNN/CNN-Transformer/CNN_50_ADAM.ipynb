# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Flatten, Dense, LayerNormalization, MultiHeadAttention, Add, Reshape, GlobalAveragePooling2D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Input
import os

# %%
# Set dataset path
data_dir = r'D:\Project\data_kaggle\aug\train_split'

# %%
batch_size = 32
img_height = 224
img_width = 224
image_size = (img_height, img_width)
epochs = int(input("Enter epochs number: "))
# Out:
# Enter epochs number:  50

# %%
train_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb'  # Force RGB mode
)
# Out:
# Found 5863 images belonging to 8 classes.

# %%
val_datagen = ImageDataGenerator()

val_data = r"D:\Project\data_kaggle\aug\val_split"

val_generator = val_datagen.flow_from_directory(
    val_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
)
# Out:
# Found 1469 images belonging to 8 classes.

# %%
def create_cnn_base(input_shape):
    inputs = Input(shape=input_shape)

    # First Conv Block
    x = Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(inputs)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)

    # Second Conv Block
    x = Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.4)(x)

    # Third Conv Block
    x = Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.5)(x)

    return inputs, x

def transformer_encoder(inputs, num_heads, key_dim, ff_dim, dropout_rate=0.1):
    # Layer Normalization and Multi-Head Attention
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim, dropout=dropout_rate)(x, x)
    x = Dropout(dropout_rate)(x)
    x = Add()([x, inputs])

    # Feed Forward Network
    y = LayerNormalization(epsilon=1e-6)(x)
    y = Dense(ff_dim, activation='relu')(y)
    y = Dropout(dropout_rate)(y)
    y = Dense(inputs.shape[-1])(y)
    outputs = Add()([y, x])

    return outputs

def create_hybrid_model(input_shape, num_classes, num_transformer_blocks=1, num_heads=4, key_dim=128, ff_dim=256, dropout_rate=0.1):
    inputs, cnn_output = create_cnn_base(input_shape)

    # Reshape CNN output for Transformer
    x = Reshape((-1, cnn_output.shape[-1]))(cnn_output)

    # Apply Transformer blocks
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, num_heads, key_dim, ff_dim, dropout_rate)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(cnn_output)

    # Fully Connected Layer
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

input_shape = (224, 224, 3)
num_classes = len(train_generator.class_indices)

model = create_hybrid_model(input_shape, num_classes)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 128,328
# Trainable params: 128,328
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)
# Out:
# Epoch 1/50
# 184/184 [==============================] - 21s 87ms/step - loss: 2.9511 - accuracy: 0.2801 - val_loss: 2.1413 - val_accuracy: 0.3710
# Epoch 2/50
# 184/184 [==============================] - 15s 81ms/step - loss: 1.9387 - accuracy: 0.3829 - val_loss: 1.9876 - val_accuracy: 0.3730
# Epoch 3/50
# 184/184 [==============================] - 15s 82ms/step - loss: 1.7756 - accuracy: 0.4552 - val_loss: 1.8304 - val_accuracy: 0.4323
# Epoch 4/50
# 184/184 [==============================] - 15s 82ms/step - loss: 1.6784 - accuracy: 0.4794 - val_loss: 1.6486 - val_accuracy: 0.5391
# Epoch 5/50
# 184/184 [==============================] - 15s 82ms/step - loss: 1.5982 - accuracy: 0.5115 - val_loss: 1.4900 - val_accuracy: 0.5705
# Epoch 6/50
# 184/184 [==============================] - 15s 83ms/step - loss: 1.4736 - accuracy: 0.5448 - val_loss: 1.5400 - val_accuracy: 0.4942
# Epoch 7/50
# 184/184 [==============================] - 15s 83ms/step - loss: 1.4070 - accuracy: 0.5741 - val_loss: 1.3785 - val_accuracy: 0.6086
# Epoch 8/50
# 184/184 [==============================] - 15s 83ms/step - loss: 1.3598 - accuracy: 0.5855 - val_loss: 1.3381 - val_accuracy: 0.6167
# Epoch 9/50
# 184/184 [==============================] - 16s 84ms/step - loss: 1.3095 - accuracy: 0.6040 - val_loss: 1.3447 - val_accuracy: 0.5950
# Epoch 10/50
# 184/184 [==============================] - 16s 84ms/step - loss: 1.1991 - accuracy: 0.6379 - val_loss: 1.3121 - val_accuracy: 0.6031
# Epoch 11/50
# 184/184 [==============================] - 16s 84ms/step - loss: 1.1990 - accuracy: 0.6410 - val_loss: 1.2323 - val_accuracy: 0.6167
# Epoch 12/50
# 184/184 [==============================] - 16s 84ms/step - loss: 1.1482 - accuracy: 0.6592 - val_loss: 1.1089 - val_accuracy: 0.6760
# Epoch 13/50
# 184/184 [==============================] - 16s 84ms/step - loss: 1.1258 - accuracy: 0.6633 - val_loss: 1.0895 - val_accuracy: 0.7025
# Epoch 14/50
# 184/184 [==============================] - 16s 84ms/step - loss: 1.0352 - accuracy: 0.7003 - val_loss: 1.0832 - val_accuracy: 0.6678
# Epoch 15/50
# 184/184 [==============================] - 16s 84ms/step - loss: 1.0260 - accuracy: 0.7020 - val_loss: 1.0308 - val_accuracy: 0.7263
# Epoch 16/50
# 184/184 [==============================] - 16s 85ms/step - loss: 1.0143 - accuracy: 0.7022 - val_loss: 1.0674 - val_accuracy: 0.6732
# Epoch 17/50
# 184/184 [==============================] - 16s 85ms/step - loss: 0.9621 - accuracy: 0.7222 - val_loss: 0.9125 - val_accuracy: 0.7679
# Epoch 18/50
# 184/184 [==============================] - 16s 87ms/step - loss: 0.9217 - accuracy: 0.7327 - val_loss: 0.9195 - val_accuracy: 0.7400
# Epoch 19/50
# 184/184 [==============================] - 16s 84ms/step - loss: 0.9637 - accuracy: 0.7309 - val_loss: 0.9390 - val_accuracy: 0.7427
# Epoch 20/50
# 184/184 [==============================] - 15s 83ms/step - loss: 0.9124 - accuracy: 0.7356 - val_loss: 0.8489 - val_accuracy: 0.7808
# Epoch 21/50
# 184/184 [==============================] - 16s 84ms/step - loss: 0.8621 - accuracy: 0.7583 - val_loss: 0.8425 - val_accuracy: 0.7815
# Epoch 22/50
# 184/184 [==============================] - 16s 85ms/step - loss: 0.8244 - accuracy: 0.7675 - val_loss: 0.7816 - val_accuracy: 0.7965
# Epoch 23/50
# 184/184 [==============================] - 16s 85ms/step - loss: 0.8671 - accuracy: 0.7551 - val_loss: 0.7555 - val_accuracy: 0.8060
# Epoch 24/50
# 184/184 [==============================] - 16s 86ms/step - loss: 0.8180 - accuracy: 0.7754 - val_loss: 0.7158 - val_accuracy: 0.8230
# Epoch 25/50
# 184/184 [==============================] - 16s 85ms/step - loss: 0.8105 - accuracy: 0.7766 - val_loss: 0.7382 - val_accuracy: 0.8128
# Epoch 26/50
# 184/184 [==============================] - 16s 85ms/step - loss: 0.7774 - accuracy: 0.7834 - val_loss: 0.8115 - val_accuracy: 0.7822
# Epoch 27/50
# 184/184 [==============================] - 15s 84ms/step - loss: 0.7752 - accuracy: 0.7904 - val_loss: 0.7351 - val_accuracy: 0.8196
# Epoch 28/50
# 184/184 [==============================] - 15s 83ms/step - loss: 0.7540 - accuracy: 0.8003 - val_loss: 0.7289 - val_accuracy: 0.8019
# Epoch 29/50
# 184/184 [==============================] - 15s 83ms/step - loss: 0.7333 - accuracy: 0.8086 - val_loss: 0.6860 - val_accuracy: 0.8237
# Epoch 30/50
# 184/184 [==============================] - 15s 84ms/step - loss: 0.7395 - accuracy: 0.8030 - val_loss: 0.7256 - val_accuracy: 0.8210
# Epoch 31/50
# 184/184 [==============================] - 16s 84ms/step - loss: 0.7462 - accuracy: 0.7962 - val_loss: 0.6647 - val_accuracy: 0.8482
# Epoch 32/50
# 184/184 [==============================] - 16s 85ms/step - loss: 0.6887 - accuracy: 0.8151 - val_loss: 0.6595 - val_accuracy: 0.8332
# Epoch 33/50
# 184/184 [==============================] - 15s 84ms/step - loss: 0.6901 - accuracy: 0.8180 - val_loss: 0.5941 - val_accuracy: 0.8591
# Epoch 34/50
# 184/184 [==============================] - 15s 84ms/step - loss: 0.6416 - accuracy: 0.8340 - val_loss: 0.6343 - val_accuracy: 0.8598
# Epoch 35/50
# 184/184 [==============================] - 15s 83ms/step - loss: 0.6661 - accuracy: 0.8231 - val_loss: 0.5931 - val_accuracy: 0.8666
# Epoch 36/50
# 184/184 [==============================] - 15s 83ms/step - loss: 0.6737 - accuracy: 0.8305 - val_loss: 0.6514 - val_accuracy: 0.8407
# Epoch 37/50
# 184/184 [==============================] - 15s 83ms/step - loss: 0.6411 - accuracy: 0.8346 - val_loss: 0.7047 - val_accuracy: 0.8087
# Epoch 38/50
# 184/184 [==============================] - 15s 83ms/step - loss: 0.6336 - accuracy: 0.8380 - val_loss: 0.5823 - val_accuracy: 0.8707
# Epoch 39/50
# 184/184 [==============================] - 16s 84ms/step - loss: 0.6221 - accuracy: 0.8482 - val_loss: 0.5621 - val_accuracy: 0.8781
# Epoch 40/50
# 184/184 [==============================] - 16s 85ms/step - loss: 0.6327 - accuracy: 0.8388 - val_loss: 0.6710 - val_accuracy: 0.8155
# Epoch 41/50
# 184/184 [==============================] - 16s 84ms/step - loss: 0.6322 - accuracy: 0.8404 - val_loss: 0.6382 - val_accuracy: 0.8373
# Epoch 42/50
# 184/184 [==============================] - 16s 84ms/step - loss: 0.6200 - accuracy: 0.8508 - val_loss: 0.6354 - val_accuracy: 0.8366
# Epoch 43/50
# 184/184 [==============================] - 15s 83ms/step - loss: 0.6247 - accuracy: 0.8484 - val_loss: 0.5994 - val_accuracy: 0.8693
# Epoch 44/50
# 184/184 [==============================] - 15s 83ms/step - loss: 0.5735 - accuracy: 0.8661 - val_loss: 0.4894 - val_accuracy: 0.9061
# Epoch 45/50
# 184/184 [==============================] - 15s 84ms/step - loss: 0.5753 - accuracy: 0.8615 - val_loss: 0.5596 - val_accuracy: 0.8822
# Epoch 46/50
# 184/184 [==============================] - 15s 83ms/step - loss: 0.5607 - accuracy: 0.8668 - val_loss: 0.5897 - val_accuracy: 0.8652
# Epoch 47/50
# 184/184 [==============================] - 15s 84ms/step - loss: 0.5570 - accuracy: 0.8728 - val_loss: 0.5935 - val_accuracy: 0.8570
# Epoch 48/50
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5717 - accuracy: 0.8651 - val_loss: 0.5288 - val_accuracy: 0.8884
# Epoch 49/50
# 184/184 [==============================] - 16s 84ms/step - loss: 0.5503 - accuracy: 0.8731 - val_loss: 0.5538 - val_accuracy: 0.8720
# Epoch 50/50
# 184/184 [==============================] - 15s 84ms/step - loss: 0.5655 - accuracy: 0.8692 - val_loss: 0.4992 - val_accuracy: 0.9108

# %%
# Plot accuracy and loss curves
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
# Evaluate model
test_data = r'D:\Project\data_kaggle\test'

eval_generator = train_datagen.flow_from_directory(
    test_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

y_true = eval_generator.classes
y_pred = model.predict(eval_generator)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# Found 190 images belonging to 8 classes.

# %%
# Print classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred_classes))

# Plot confusion matrix
conf_mat = confusion_matrix(y_true, y_pred_classes)
class_labels = list(train_generator.class_indices.keys())
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        28
#            1       0.82      0.67      0.74        21
#            2       0.85      0.92      0.88        25
#            3       0.86      0.83      0.84        23
#            4       0.73      0.76      0.74        21
#            5       0.75      0.65      0.70        23
#            6       0.81      0.96      0.88        26
#            7       0.96      0.96      0.96        23
#
#     accuracy                           0.85       190
#    macro avg       0.85      0.84      0.84       190
# weighted avg       0.85      0.85      0.85       190

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="viridis", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('Actual', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)
plt.show()

# %%
model_version = epochs
next_version = str(int(model_version) + 10)

# %%
import shutil

notebook_filename = f"CNN_{model_version}_ADAM.ipynb"
new_notebook_filename = f"CNN_{next_version}_ADAM.ipynb"

shutil.copy(notebook_filename, new_notebook_filename)
print(f"Notebook copied as {new_notebook_filename}")
# Out:
# Notebook copied as CNN_60_ADAM.ipynb

# %%
os._exit(00)
