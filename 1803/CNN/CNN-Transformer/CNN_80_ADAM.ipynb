# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Flatten, Dense, LayerNormalization, MultiHeadAttention, Add, Reshape, GlobalAveragePooling2D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Input
import os

# %%
# Set dataset path
data_dir = r'D:\Project\data_kaggle\aug\train_split'

# %%
batch_size = 32
img_height = 224
img_width = 224
image_size = (img_height, img_width)
epochs = int(input("Enter epochs number: "))
# Out:
# Enter epochs number:  80

# %%
train_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb'  # Force RGB mode
)
# Out:
# Found 5863 images belonging to 8 classes.

# %%
val_datagen = ImageDataGenerator()

val_data = r"D:\Project\data_kaggle\aug\val_split"

val_generator = val_datagen.flow_from_directory(
    val_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
)
# Out:
# Found 1469 images belonging to 8 classes.

# %%
def create_cnn_base(input_shape):
    inputs = Input(shape=input_shape)

    # First Conv Block
    x = Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(inputs)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)

    # Second Conv Block
    x = Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.4)(x)

    # Third Conv Block
    x = Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.5)(x)

    return inputs, x

def transformer_encoder(inputs, num_heads, key_dim, ff_dim, dropout_rate=0.1):
    # Layer Normalization and Multi-Head Attention
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim, dropout=dropout_rate)(x, x)
    x = Dropout(dropout_rate)(x)
    x = Add()([x, inputs])

    # Feed Forward Network
    y = LayerNormalization(epsilon=1e-6)(x)
    y = Dense(ff_dim, activation='relu')(y)
    y = Dropout(dropout_rate)(y)
    y = Dense(inputs.shape[-1])(y)
    outputs = Add()([y, x])

    return outputs

def create_hybrid_model(input_shape, num_classes, num_transformer_blocks=1, num_heads=4, key_dim=128, ff_dim=256, dropout_rate=0.1):
    inputs, cnn_output = create_cnn_base(input_shape)

    # Reshape CNN output for Transformer
    x = Reshape((-1, cnn_output.shape[-1]))(cnn_output)

    # Apply Transformer blocks
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, num_heads, key_dim, ff_dim, dropout_rate)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(cnn_output)

    # Fully Connected Layer
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

input_shape = (224, 224, 3)
num_classes = len(train_generator.class_indices)

model = create_hybrid_model(input_shape, num_classes)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 128,328
# Trainable params: 128,328
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)
# Out:
# Epoch 1/80
# 184/184 [==============================] - 27s 113ms/step - loss: 3.9461 - accuracy: 0.2296 - val_loss: 2.2003 - val_accuracy: 0.3342
# Epoch 2/80
# 184/184 [==============================] - 16s 86ms/step - loss: 2.0164 - accuracy: 0.3430 - val_loss: 2.0886 - val_accuracy: 0.3737
# Epoch 3/80
# 184/184 [==============================] - 15s 83ms/step - loss: 1.8789 - accuracy: 0.3976 - val_loss: 1.8614 - val_accuracy: 0.4214
# Epoch 4/80
# 184/184 [==============================] - 15s 82ms/step - loss: 1.7776 - accuracy: 0.4342 - val_loss: 1.7503 - val_accuracy: 0.4670
# Epoch 5/80
# 184/184 [==============================] - 15s 84ms/step - loss: 1.6596 - accuracy: 0.4880 - val_loss: 1.6903 - val_accuracy: 0.4847
# Epoch 6/80
# 184/184 [==============================] - 15s 83ms/step - loss: 1.5584 - accuracy: 0.5171 - val_loss: 1.5009 - val_accuracy: 0.5575
# Epoch 7/80
# 184/184 [==============================] - 16s 84ms/step - loss: 1.4792 - accuracy: 0.5383 - val_loss: 1.4666 - val_accuracy: 0.5562
# Epoch 8/80
# 184/184 [==============================] - 17s 92ms/step - loss: 1.4218 - accuracy: 0.5690 - val_loss: 1.4220 - val_accuracy: 0.5943
# Epoch 9/80
# 184/184 [==============================] - 16s 86ms/step - loss: 1.3093 - accuracy: 0.6069 - val_loss: 1.2813 - val_accuracy: 0.6433
# Epoch 10/80
# 184/184 [==============================] - 16s 85ms/step - loss: 1.2403 - accuracy: 0.6299 - val_loss: 1.1992 - val_accuracy: 0.6562
# Epoch 11/80
# 184/184 [==============================] - 16s 85ms/step - loss: 1.2075 - accuracy: 0.6408 - val_loss: 1.1490 - val_accuracy: 0.6692
# Epoch 12/80
# 184/184 [==============================] - 17s 90ms/step - loss: 1.1900 - accuracy: 0.6449 - val_loss: 1.1608 - val_accuracy: 0.6549
# Epoch 13/80
# 184/184 [==============================] - 17s 91ms/step - loss: 1.1660 - accuracy: 0.6514 - val_loss: 1.1337 - val_accuracy: 0.6835
# Epoch 14/80
# 184/184 [==============================] - 17s 93ms/step - loss: 1.1035 - accuracy: 0.6689 - val_loss: 1.0754 - val_accuracy: 0.7468
# Epoch 15/80
# 184/184 [==============================] - 17s 91ms/step - loss: 1.0603 - accuracy: 0.6938 - val_loss: 0.9994 - val_accuracy: 0.7372
# Epoch 16/80
# 184/184 [==============================] - 17s 94ms/step - loss: 1.0423 - accuracy: 0.6886 - val_loss: 1.0962 - val_accuracy: 0.6692
# Epoch 17/80
# 184/184 [==============================] - 17s 89ms/step - loss: 0.9936 - accuracy: 0.7090 - val_loss: 0.9797 - val_accuracy: 0.7114
# Epoch 18/80
# 184/184 [==============================] - 18s 96ms/step - loss: 1.0095 - accuracy: 0.7073 - val_loss: 0.9529 - val_accuracy: 0.7127
# Epoch 19/80
# 184/184 [==============================] - 17s 90ms/step - loss: 0.9675 - accuracy: 0.7210 - val_loss: 0.8830 - val_accuracy: 0.7699
# Epoch 20/80
# 184/184 [==============================] - 16s 89ms/step - loss: 0.9057 - accuracy: 0.7436 - val_loss: 0.9120 - val_accuracy: 0.7713
# Epoch 21/80
# 184/184 [==============================] - 16s 88ms/step - loss: 0.8835 - accuracy: 0.7552 - val_loss: 0.8622 - val_accuracy: 0.7699
# Epoch 22/80
# 184/184 [==============================] - 16s 88ms/step - loss: 0.8859 - accuracy: 0.7500 - val_loss: 0.9262 - val_accuracy: 0.7583
# Epoch 23/80
# 184/184 [==============================] - 17s 91ms/step - loss: 0.8625 - accuracy: 0.7585 - val_loss: 0.9358 - val_accuracy: 0.7168
# Epoch 24/80
# 184/184 [==============================] - 16s 89ms/step - loss: 0.8200 - accuracy: 0.7689 - val_loss: 0.8323 - val_accuracy: 0.7611
# Epoch 25/80
# 184/184 [==============================] - 16s 88ms/step - loss: 0.8332 - accuracy: 0.7607 - val_loss: 0.7487 - val_accuracy: 0.8128
# Epoch 26/80
# 184/184 [==============================] - 17s 94ms/step - loss: 0.7931 - accuracy: 0.7757 - val_loss: 0.8562 - val_accuracy: 0.7454
# Epoch 27/80
# 184/184 [==============================] - 17s 93ms/step - loss: 0.7864 - accuracy: 0.7824 - val_loss: 0.7917 - val_accuracy: 0.7808
# Epoch 28/80
# 184/184 [==============================] - 17s 93ms/step - loss: 0.7906 - accuracy: 0.7805 - val_loss: 0.7621 - val_accuracy: 0.8271
# Epoch 29/80
# 184/184 [==============================] - 18s 99ms/step - loss: 0.7973 - accuracy: 0.7713 - val_loss: 0.7041 - val_accuracy: 0.8182
# Epoch 30/80
# 184/184 [==============================] - 17s 90ms/step - loss: 0.7404 - accuracy: 0.7977 - val_loss: 0.6669 - val_accuracy: 0.8380
# Epoch 31/80
# 184/184 [==============================] - 16s 85ms/step - loss: 0.7231 - accuracy: 0.8073 - val_loss: 0.9078 - val_accuracy: 0.7474
# Epoch 32/80
# 184/184 [==============================] - 16s 89ms/step - loss: 0.7255 - accuracy: 0.8021 - val_loss: 0.6219 - val_accuracy: 0.8530
# Epoch 33/80
# 184/184 [==============================] - 17s 89ms/step - loss: 0.7091 - accuracy: 0.8110 - val_loss: 0.7447 - val_accuracy: 0.8087
# Epoch 34/80
# 184/184 [==============================] - 16s 87ms/step - loss: 0.7185 - accuracy: 0.8076 - val_loss: 0.8177 - val_accuracy: 0.7474
# Epoch 35/80
# 184/184 [==============================] - 16s 88ms/step - loss: 0.7267 - accuracy: 0.8069 - val_loss: 0.7243 - val_accuracy: 0.8182
# Epoch 36/80
# 184/184 [==============================] - 16s 87ms/step - loss: 0.6989 - accuracy: 0.8127 - val_loss: 0.7065 - val_accuracy: 0.8237
# Epoch 37/80
# 184/184 [==============================] - 16s 87ms/step - loss: 0.6684 - accuracy: 0.8243 - val_loss: 0.6498 - val_accuracy: 0.8312
# Epoch 38/80
# 184/184 [==============================] - 16s 88ms/step - loss: 0.6549 - accuracy: 0.8233 - val_loss: 0.6924 - val_accuracy: 0.8087
# Epoch 39/80
# 184/184 [==============================] - 16s 85ms/step - loss: 0.6178 - accuracy: 0.8415 - val_loss: 0.7015 - val_accuracy: 0.8176
# Epoch 40/80
# 184/184 [==============================] - 16s 87ms/step - loss: 0.6700 - accuracy: 0.8265 - val_loss: 0.7964 - val_accuracy: 0.7692
# Epoch 41/80
# 184/184 [==============================] - 17s 93ms/step - loss: 0.6393 - accuracy: 0.8409 - val_loss: 0.5997 - val_accuracy: 0.8625
# Epoch 42/80
# 184/184 [==============================] - 17s 90ms/step - loss: 0.6297 - accuracy: 0.8325 - val_loss: 0.6687 - val_accuracy: 0.8223
# Epoch 43/80
# 184/184 [==============================] - 17s 90ms/step - loss: 0.6448 - accuracy: 0.8339 - val_loss: 0.6581 - val_accuracy: 0.8244
# Epoch 44/80
# 184/184 [==============================] - 17s 91ms/step - loss: 0.6162 - accuracy: 0.8473 - val_loss: 0.6397 - val_accuracy: 0.8237
# Epoch 45/80
# 184/184 [==============================] - 16s 84ms/step - loss: 0.6125 - accuracy: 0.8496 - val_loss: 0.6794 - val_accuracy: 0.8155
# Epoch 46/80
# 184/184 [==============================] - 16s 87ms/step - loss: 0.6078 - accuracy: 0.8448 - val_loss: 0.5941 - val_accuracy: 0.8550
# Epoch 47/80
# 184/184 [==============================] - 16s 87ms/step - loss: 0.6095 - accuracy: 0.8467 - val_loss: 0.5844 - val_accuracy: 0.8747
# Epoch 48/80
# 184/184 [==============================] - 17s 93ms/step - loss: 0.5991 - accuracy: 0.8537 - val_loss: 0.6043 - val_accuracy: 0.8502
# Epoch 49/80
# 184/184 [==============================] - 17s 91ms/step - loss: 0.5679 - accuracy: 0.8670 - val_loss: 0.5700 - val_accuracy: 0.8625
# Epoch 50/80
# 184/184 [==============================] - 17s 91ms/step - loss: 0.5707 - accuracy: 0.8605 - val_loss: 0.5471 - val_accuracy: 0.8768
# Epoch 51/80
# 184/184 [==============================] - 17s 90ms/step - loss: 0.5806 - accuracy: 0.8627 - val_loss: 0.7919 - val_accuracy: 0.7971
# Epoch 52/80
# 184/184 [==============================] - 18s 95ms/step - loss: 0.5678 - accuracy: 0.8630 - val_loss: 0.5659 - val_accuracy: 0.8666
# Epoch 53/80
# 184/184 [==============================] - 16s 84ms/step - loss: 0.5680 - accuracy: 0.8610 - val_loss: 0.6122 - val_accuracy: 0.8339
# Epoch 54/80
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5922 - accuracy: 0.8598 - val_loss: 0.6068 - val_accuracy: 0.8727
# Epoch 55/80
# 184/184 [==============================] - 16s 86ms/step - loss: 0.5347 - accuracy: 0.8762 - val_loss: 0.5617 - val_accuracy: 0.8652
# Epoch 56/80
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5452 - accuracy: 0.8721 - val_loss: 0.5297 - val_accuracy: 0.8850
# Epoch 57/80
# 184/184 [==============================] - 16s 86ms/step - loss: 0.5837 - accuracy: 0.8613 - val_loss: 0.6410 - val_accuracy: 0.8496
# Epoch 58/80
# 184/184 [==============================] - 16s 84ms/step - loss: 0.5486 - accuracy: 0.8769 - val_loss: 0.5214 - val_accuracy: 0.8775
# Epoch 59/80
# 184/184 [==============================] - 16s 84ms/step - loss: 0.5080 - accuracy: 0.8866 - val_loss: 0.5455 - val_accuracy: 0.8781
# Epoch 60/80
# 184/184 [==============================] - 16s 86ms/step - loss: 0.5604 - accuracy: 0.8700 - val_loss: 0.6027 - val_accuracy: 0.8543
# Epoch 61/80
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5221 - accuracy: 0.8823 - val_loss: 0.5120 - val_accuracy: 0.8890
# Epoch 62/80
# 184/184 [==============================] - 16s 88ms/step - loss: 0.5208 - accuracy: 0.8856 - val_loss: 0.5961 - val_accuracy: 0.8448
# Epoch 63/80
# 184/184 [==============================] - 16s 84ms/step - loss: 0.5179 - accuracy: 0.8864 - val_loss: 0.6896 - val_accuracy: 0.8108
# Epoch 64/80
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5345 - accuracy: 0.8792 - val_loss: 0.5258 - val_accuracy: 0.8870
# Epoch 65/80
# 184/184 [==============================] - 16s 86ms/step - loss: 0.5109 - accuracy: 0.8864 - val_loss: 0.5167 - val_accuracy: 0.8836
# Epoch 66/80
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5063 - accuracy: 0.8915 - val_loss: 0.4951 - val_accuracy: 0.8931
# Epoch 67/80
# 184/184 [==============================] - 16s 85ms/step - loss: 0.4965 - accuracy: 0.8934 - val_loss: 0.5457 - val_accuracy: 0.8713
# Epoch 68/80
# 184/184 [==============================] - 16s 88ms/step - loss: 0.5137 - accuracy: 0.8896 - val_loss: 0.5290 - val_accuracy: 0.8870
# Epoch 69/80
# 184/184 [==============================] - 16s 89ms/step - loss: 0.5324 - accuracy: 0.8808 - val_loss: 0.5599 - val_accuracy: 0.8734
# Epoch 70/80
# 184/184 [==============================] - 17s 90ms/step - loss: 0.4850 - accuracy: 0.8987 - val_loss: 0.6653 - val_accuracy: 0.8387
# Epoch 71/80
# 184/184 [==============================] - 16s 87ms/step - loss: 0.4937 - accuracy: 0.8948 - val_loss: 0.6534 - val_accuracy: 0.8298
# Epoch 72/80
# 184/184 [==============================] - 16s 86ms/step - loss: 0.5081 - accuracy: 0.8903 - val_loss: 0.4877 - val_accuracy: 0.9074
# Epoch 73/80
# 184/184 [==============================] - 17s 90ms/step - loss: 0.4865 - accuracy: 0.8963 - val_loss: 0.5381 - val_accuracy: 0.8686
# Epoch 74/80
# 184/184 [==============================] - 17s 90ms/step - loss: 0.5204 - accuracy: 0.8891 - val_loss: 0.5221 - val_accuracy: 0.8918
# Epoch 75/80
# 184/184 [==============================] - 17s 90ms/step - loss: 0.5115 - accuracy: 0.8890 - val_loss: 0.5085 - val_accuracy: 0.8890
# Epoch 76/80
# 184/184 [==============================] - 16s 88ms/step - loss: 0.4796 - accuracy: 0.9018 - val_loss: 0.5226 - val_accuracy: 0.8781
# Epoch 77/80
# 184/184 [==============================] - 16s 85ms/step - loss: 0.4537 - accuracy: 0.9070 - val_loss: 0.5374 - val_accuracy: 0.8781
# Epoch 78/80
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5050 - accuracy: 0.8900 - val_loss: 0.5833 - val_accuracy: 0.8645
# Epoch 79/80
# 184/184 [==============================] - 17s 90ms/step - loss: 0.4843 - accuracy: 0.9002 - val_loss: 0.4669 - val_accuracy: 0.9033
# Epoch 80/80
# 184/184 [==============================] - 16s 86ms/step - loss: 0.4727 - accuracy: 0.8978 - val_loss: 0.5619 - val_accuracy: 0.8693

# %%
# Plot accuracy and loss curves
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
# Evaluate model
test_data = r'D:\Project\data_kaggle\test'

eval_generator = train_datagen.flow_from_directory(
    test_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

y_true = eval_generator.classes
y_pred = model.predict(eval_generator)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)  # Fix tf.argmax issue
# Out:
# Found 190 images belonging to 8 classes.

# %%
# Print classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred_classes))

# Plot confusion matrix
conf_mat = confusion_matrix(y_true, y_pred_classes)
class_labels = list(train_generator.class_indices.keys())
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97        28
#            1       0.56      0.43      0.49        21
#            2       0.91      0.84      0.88        25
#            3       0.91      0.43      0.59        23
#            4       0.42      0.90      0.58        21
#            5       0.89      0.35      0.50        23
#            6       0.81      1.00      0.90        26
#            7       0.88      0.91      0.89        23
#
#     accuracy                           0.75       190
#    macro avg       0.79      0.73      0.72       190
# weighted avg       0.80      0.75      0.74       190

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="viridis", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('Actual', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)
plt.show()

# %%
model_version = epochs
next_version = str(int(model_version) + 10)

# %%
import shutil

notebook_filename = f"CNN_{model_version}_ADAM.ipynb"
new_notebook_filename = f"CNN_{next_version}_ADAM.ipynb"

shutil.copy(notebook_filename, new_notebook_filename)
print(f"Notebook copied as {new_notebook_filename}")
# Out:
# Notebook copied as CNN_90_ADAM.ipynb

# %%
os._exit(00)
