# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Flatten, Dense, LayerNormalization, MultiHeadAttention, Add, Reshape, GlobalAveragePooling2D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Input
import os

# %%
# Set dataset path
data_dir = r'D:\Project\data_kaggle\aug\train_split'

# %%
batch_size = 32
img_height = 224
img_width = 224
image_size = (img_height, img_width)
epochs = int(input("Enter epochs number: "))
# Out:
# Enter epochs number:  90

# %%
train_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb'  # Force RGB mode
)
# Out:
# Found 5863 images belonging to 8 classes.

# %%
val_datagen = ImageDataGenerator()

val_data = r"D:\Project\data_kaggle\aug\val_split"

val_generator = val_datagen.flow_from_directory(
    val_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
)
# Out:
# Found 1469 images belonging to 8 classes.

# %%
def create_cnn_base(input_shape):
    inputs = Input(shape=input_shape)

    # First Conv Block
    x = Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(inputs)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)

    # Second Conv Block
    x = Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.4)(x)

    # Third Conv Block
    x = Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.5)(x)

    return inputs, x

def transformer_encoder(inputs, num_heads, key_dim, ff_dim, dropout_rate=0.1):
    # Layer Normalization and Multi-Head Attention
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim, dropout=dropout_rate)(x, x)
    x = Dropout(dropout_rate)(x)
    x = Add()([x, inputs])

    # Feed Forward Network
    y = LayerNormalization(epsilon=1e-6)(x)
    y = Dense(ff_dim, activation='relu')(y)
    y = Dropout(dropout_rate)(y)
    y = Dense(inputs.shape[-1])(y)
    outputs = Add()([y, x])

    return outputs

def create_hybrid_model(input_shape, num_classes, num_transformer_blocks=1, num_heads=4, key_dim=128, ff_dim=256, dropout_rate=0.1):
    inputs, cnn_output = create_cnn_base(input_shape)

    # Reshape CNN output for Transformer
    x = Reshape((-1, cnn_output.shape[-1]))(cnn_output)

    # Apply Transformer blocks
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, num_heads, key_dim, ff_dim, dropout_rate)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(cnn_output)

    # Fully Connected Layer
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

input_shape = (224, 224, 3)
num_classes = len(train_generator.class_indices)

model = create_hybrid_model(input_shape, num_classes)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 128,328
# Trainable params: 128,328
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)
# Out:
# Epoch 1/90
# 184/184 [==============================] - 23s 94ms/step - loss: 3.9292 - accuracy: 0.2359 - val_loss: 2.2029 - val_accuracy: 0.2818
# Epoch 2/90
# 184/184 [==============================] - 23s 126ms/step - loss: 2.0307 - accuracy: 0.3239 - val_loss: 2.1282 - val_accuracy: 0.3363
# Epoch 3/90
# 184/184 [==============================] - 46s 247ms/step - loss: 1.9019 - accuracy: 0.3657 - val_loss: 1.9438 - val_accuracy: 0.3867
# Epoch 4/90
# 184/184 [==============================] - 46s 246ms/step - loss: 1.8267 - accuracy: 0.4054 - val_loss: 1.8450 - val_accuracy: 0.4255
# Epoch 5/90
# 184/184 [==============================] - 46s 248ms/step - loss: 1.7374 - accuracy: 0.4424 - val_loss: 1.7710 - val_accuracy: 0.4486
# Epoch 6/90
# 184/184 [==============================] - 47s 254ms/step - loss: 1.6582 - accuracy: 0.4779 - val_loss: 1.6061 - val_accuracy: 0.5133
# Epoch 7/90
# 184/184 [==============================] - 47s 254ms/step - loss: 1.5484 - accuracy: 0.5107 - val_loss: 1.5258 - val_accuracy: 0.5310
# Epoch 8/90
# 184/184 [==============================] - 46s 246ms/step - loss: 1.4439 - accuracy: 0.5499 - val_loss: 1.5043 - val_accuracy: 0.5521
# Epoch 9/90
# 184/184 [==============================] - 46s 252ms/step - loss: 1.3803 - accuracy: 0.5763 - val_loss: 1.4613 - val_accuracy: 0.5507
# Epoch 10/90
# 184/184 [==============================] - 45s 247ms/step - loss: 1.3147 - accuracy: 0.5951 - val_loss: 1.2350 - val_accuracy: 0.6487
# Epoch 11/90
# 184/184 [==============================] - 47s 253ms/step - loss: 1.2747 - accuracy: 0.6026 - val_loss: 1.2108 - val_accuracy: 0.6399
# Epoch 12/90
# 184/184 [==============================] - 47s 255ms/step - loss: 1.2204 - accuracy: 0.6302 - val_loss: 1.2061 - val_accuracy: 0.6406
# Epoch 13/90
# 184/184 [==============================] - 46s 249ms/step - loss: 1.1668 - accuracy: 0.6452 - val_loss: 1.1965 - val_accuracy: 0.6583
# Epoch 14/90
# 184/184 [==============================] - 46s 248ms/step - loss: 1.1989 - accuracy: 0.6333 - val_loss: 1.1507 - val_accuracy: 0.6794
# Epoch 15/90
# 184/184 [==============================] - 48s 259ms/step - loss: 1.1138 - accuracy: 0.6643 - val_loss: 1.0685 - val_accuracy: 0.6767
# Epoch 16/90
# 184/184 [==============================] - 47s 255ms/step - loss: 1.0703 - accuracy: 0.6793 - val_loss: 0.9833 - val_accuracy: 0.7427
# Epoch 17/90
# 184/184 [==============================] - 47s 256ms/step - loss: 1.0880 - accuracy: 0.6744 - val_loss: 1.0441 - val_accuracy: 0.7080
# Epoch 18/90
# 184/184 [==============================] - 47s 255ms/step - loss: 1.0286 - accuracy: 0.7000 - val_loss: 1.0797 - val_accuracy: 0.6821
# Epoch 19/90
# 184/184 [==============================] - 47s 255ms/step - loss: 1.0028 - accuracy: 0.7049 - val_loss: 0.9764 - val_accuracy: 0.7386
# Epoch 20/90
# 184/184 [==============================] - 46s 251ms/step - loss: 1.0198 - accuracy: 0.6991 - val_loss: 1.0290 - val_accuracy: 0.7250
# Epoch 21/90
# 184/184 [==============================] - 47s 257ms/step - loss: 0.9942 - accuracy: 0.7054 - val_loss: 0.9087 - val_accuracy: 0.7726
# Epoch 22/90
# 184/184 [==============================] - 46s 247ms/step - loss: 0.9281 - accuracy: 0.7300 - val_loss: 0.8907 - val_accuracy: 0.7590
# Epoch 23/90
# 184/184 [==============================] - 45s 243ms/step - loss: 0.9256 - accuracy: 0.7326 - val_loss: 1.0297 - val_accuracy: 0.7216
# Epoch 24/90
# 184/184 [==============================] - 47s 255ms/step - loss: 0.9291 - accuracy: 0.7363 - val_loss: 0.8464 - val_accuracy: 0.7862
# Epoch 25/90
# Epoch 81/90
# 184/184 [==============================] - 46s 247ms/step - loss: 0.5062 - accuracy: 0.8900 - val_loss: 0.5126 - val_accuracy: 0.8727
# Epoch 82/90
# 184/184 [==============================] - 47s 254ms/step - loss: 0.5006 - accuracy: 0.8941 - val_loss: 0.5165 - val_accuracy: 0.8897
# Epoch 83/90
# 184/184 [==============================] - 47s 253ms/step - loss: 0.4857 - accuracy: 0.9002 - val_loss: 0.4217 - val_accuracy: 0.9299
# Epoch 84/90
# 184/184 [==============================] - 47s 254ms/step - loss: 0.4665 - accuracy: 0.9040 - val_loss: 0.5670 - val_accuracy: 0.8659
# Epoch 85/90
# 184/184 [==============================] - 45s 247ms/step - loss: 0.4775 - accuracy: 0.9030 - val_loss: 0.5217 - val_accuracy: 0.8890
# Epoch 86/90
# 184/184 [==============================] - 47s 254ms/step - loss: 0.4974 - accuracy: 0.8929 - val_loss: 0.4759 - val_accuracy: 0.9067
# Epoch 87/90
# 184/184 [==============================] - 47s 254ms/step - loss: 0.4843 - accuracy: 0.8980 - val_loss: 0.4481 - val_accuracy: 0.9149
# Epoch 88/90
# 184/184 [==============================] - 47s 253ms/step - loss: 0.4746 - accuracy: 0.9040 - val_loss: 0.4170 - val_accuracy: 0.9258
# Epoch 89/90
# 184/184 [==============================] - 45s 245ms/step - loss: 0.4536 - accuracy: 0.9116 - val_loss: 0.4668 - val_accuracy: 0.9115
# Epoch 90/90
# 184/184 [==============================] - 47s 251ms/step - loss: 0.4935 - accuracy: 0.8973 - val_loss: 0.5558 - val_accuracy: 0.8666

# %%
# Plot accuracy and loss curves
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
# Evaluate model
test_data = r'D:\Project\data_kaggle\test'

eval_generator = train_datagen.flow_from_directory(
    test_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

y_true = eval_generator.classes
y_pred = model.predict(eval_generator)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)  # Fix tf.argmax issue
# Out:
# Found 190 images belonging to 8 classes.

# %%
# Print classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred_classes))

# Plot confusion matrix
conf_mat = confusion_matrix(y_true, y_pred_classes)
class_labels = list(train_generator.class_indices.keys())
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        28
#            1       0.88      0.71      0.79        21
#            2       0.95      0.76      0.84        25
#            3       0.85      0.48      0.61        23
#            4       0.47      0.90      0.62        21
#            5       0.88      0.61      0.72        23
#            6       0.88      0.88      0.88        26
#            7       0.79      1.00      0.88        23
#
#     accuracy                           0.80       190
#    macro avg       0.83      0.79      0.79       190
# weighted avg       0.84      0.80      0.80       190

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="viridis", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('Actual', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)
plt.show()

# %%
model_version = epochs
next_version = str(int(model_version) + 10)

# %%
import shutil

notebook_filename = f"CNN_{model_version}_ADAM.ipynb"
new_notebook_filename = f"CNN_{next_version}_ADAM.ipynb"

shutil.copy(notebook_filename, new_notebook_filename)
print(f"Notebook copied as {new_notebook_filename}")
# Out:
# Notebook copied as CNN_100_ADAM.ipynb

# %%
os._exit(00)
