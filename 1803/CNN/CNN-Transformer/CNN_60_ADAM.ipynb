# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Flatten, Dense, LayerNormalization, MultiHeadAttention, Add, Reshape, GlobalAveragePooling2D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Input
import os

# %%
# Set dataset path
data_dir = r'D:\Project\data_kaggle\aug\train_split'

# %%
batch_size = 32
img_height = 224
img_width = 224
image_size = (img_height, img_width)
epochs = int(input("Enter epochs number: "))
# Out:
# Enter epochs number:  60

# %%
train_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb'  # Force RGB mode
)
# Out:
# Found 5863 images belonging to 8 classes.

# %%
val_datagen = ImageDataGenerator()

val_data = r"D:\Project\data_kaggle\aug\val_split"

val_generator = val_datagen.flow_from_directory(
    val_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
)
# Out:
# Found 1469 images belonging to 8 classes.

# %%
def create_cnn_base(input_shape):
    inputs = Input(shape=input_shape)

    # First Conv Block
    x = Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(inputs)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)

    # Second Conv Block
    x = Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.4)(x)

    # Third Conv Block
    x = Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.001))(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.5)(x)

    return inputs, x

def transformer_encoder(inputs, num_heads, key_dim, ff_dim, dropout_rate=0.1):
    # Layer Normalization and Multi-Head Attention
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim, dropout=dropout_rate)(x, x)
    x = Dropout(dropout_rate)(x)
    x = Add()([x, inputs])

    # Feed Forward Network
    y = LayerNormalization(epsilon=1e-6)(x)
    y = Dense(ff_dim, activation='relu')(y)
    y = Dropout(dropout_rate)(y)
    y = Dense(inputs.shape[-1])(y)
    outputs = Add()([y, x])

    return outputs

def create_hybrid_model(input_shape, num_classes, num_transformer_blocks=1, num_heads=4, key_dim=128, ff_dim=256, dropout_rate=0.1):
    inputs, cnn_output = create_cnn_base(input_shape)

    # Reshape CNN output for Transformer
    x = Reshape((-1, cnn_output.shape[-1]))(cnn_output)

    # Apply Transformer blocks
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, num_heads, key_dim, ff_dim, dropout_rate)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(cnn_output)

    # Fully Connected Layer
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

input_shape = (224, 224, 3)
num_classes = len(train_generator.class_indices)

model = create_hybrid_model(input_shape, num_classes)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 128,328
# Trainable params: 128,328
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)
# Out:
# Epoch 1/60
# 184/184 [==============================] - 21s 86ms/step - loss: 3.5957 - accuracy: 0.2175 - val_loss: 2.1900 - val_accuracy: 0.2961
# Epoch 2/60
# 184/184 [==============================] - 15s 81ms/step - loss: 2.0466 - accuracy: 0.3249 - val_loss: 2.1092 - val_accuracy: 0.3213
# Epoch 3/60
# 184/184 [==============================] - 15s 81ms/step - loss: 1.9077 - accuracy: 0.3862 - val_loss: 1.8993 - val_accuracy: 0.4132
# Epoch 4/60
# 184/184 [==============================] - 15s 81ms/step - loss: 1.7836 - accuracy: 0.4290 - val_loss: 1.7805 - val_accuracy: 0.4615
# Epoch 5/60
# 184/184 [==============================] - 15s 82ms/step - loss: 1.6706 - accuracy: 0.4711 - val_loss: 1.5779 - val_accuracy: 0.5344
# Epoch 6/60
# 184/184 [==============================] - 15s 81ms/step - loss: 1.5381 - accuracy: 0.5088 - val_loss: 1.5505 - val_accuracy: 0.5228
# Epoch 7/60
# 184/184 [==============================] - 15s 82ms/step - loss: 1.4804 - accuracy: 0.5386 - val_loss: 1.5063 - val_accuracy: 0.5371
# Epoch 8/60
# 184/184 [==============================] - 15s 83ms/step - loss: 1.4032 - accuracy: 0.5627 - val_loss: 1.3148 - val_accuracy: 0.6222
# Epoch 9/60
# 184/184 [==============================] - 15s 82ms/step - loss: 1.3254 - accuracy: 0.5983 - val_loss: 1.2884 - val_accuracy: 0.6440
# Epoch 10/60
# 184/184 [==============================] - 15s 83ms/step - loss: 1.2686 - accuracy: 0.6266 - val_loss: 1.2625 - val_accuracy: 0.6453
# Epoch 11/60
# 184/184 [==============================] - 15s 82ms/step - loss: 1.2227 - accuracy: 0.6364 - val_loss: 1.1743 - val_accuracy: 0.6712
# Epoch 12/60
# 184/184 [==============================] - 15s 82ms/step - loss: 1.2110 - accuracy: 0.6428 - val_loss: 1.2950 - val_accuracy: 0.6276
# Epoch 13/60
# 184/184 [==============================] - 15s 82ms/step - loss: 1.1425 - accuracy: 0.6626 - val_loss: 1.0742 - val_accuracy: 0.7100
# Epoch 14/60
# 184/184 [==============================] - 15s 83ms/step - loss: 1.1159 - accuracy: 0.6686 - val_loss: 1.1221 - val_accuracy: 0.6508
# Epoch 15/60
# 184/184 [==============================] - 15s 83ms/step - loss: 1.0911 - accuracy: 0.6787 - val_loss: 1.0832 - val_accuracy: 0.6923
# Epoch 16/60
# 184/184 [==============================] - 16s 85ms/step - loss: 1.0421 - accuracy: 0.7002 - val_loss: 1.0918 - val_accuracy: 0.6875
# Epoch 17/60
# 184/184 [==============================] - 15s 83ms/step - loss: 1.0759 - accuracy: 0.6807 - val_loss: 1.0052 - val_accuracy: 0.7536
# Epoch 18/60
# 184/184 [==============================] - 15s 83ms/step - loss: 1.0243 - accuracy: 0.7029 - val_loss: 0.9851 - val_accuracy: 0.7359
# Epoch 19/60
# 184/184 [==============================] - 15s 83ms/step - loss: 0.9507 - accuracy: 0.7276 - val_loss: 0.9249 - val_accuracy: 0.7726
# Epoch 20/60
# 184/184 [==============================] - 15s 83ms/step - loss: 0.9594 - accuracy: 0.7218 - val_loss: 0.9245 - val_accuracy: 0.7849
# Epoch 21/60
# 184/184 [==============================] - 16s 84ms/step - loss: 0.8974 - accuracy: 0.7503 - val_loss: 0.8398 - val_accuracy: 0.7815
# Epoch 22/60
# 184/184 [==============================] - 15s 82ms/step - loss: 0.9202 - accuracy: 0.7402 - val_loss: 0.7914 - val_accuracy: 0.8291
# Epoch 23/60
# 184/184 [==============================] - 15s 82ms/step - loss: 0.8456 - accuracy: 0.7621 - val_loss: 0.7675 - val_accuracy: 0.8189
# Epoch 24/60
# 184/184 [==============================] - 15s 84ms/step - loss: 0.8532 - accuracy: 0.7626 - val_loss: 0.9244 - val_accuracy: 0.7366
# Epoch 25/60
# 184/184 [==============================] - 15s 83ms/step - loss: 0.8489 - accuracy: 0.7699 - val_loss: 0.8209 - val_accuracy: 0.7726
# Epoch 26/60
# 184/184 [==============================] - 15s 83ms/step - loss: 0.8172 - accuracy: 0.7752 - val_loss: 0.7608 - val_accuracy: 0.8264
# Epoch 27/60
# 184/184 [==============================] - 15s 82ms/step - loss: 0.7907 - accuracy: 0.7897 - val_loss: 0.7533 - val_accuracy: 0.8176
# Epoch 28/60
# 184/184 [==============================] - 15s 83ms/step - loss: 0.7718 - accuracy: 0.7875 - val_loss: 0.7055 - val_accuracy: 0.8251
# Epoch 29/60
# 184/184 [==============================] - 16s 87ms/step - loss: 0.7545 - accuracy: 0.7945 - val_loss: 0.7179 - val_accuracy: 0.8189
# Epoch 30/60
# 184/184 [==============================] - 16s 86ms/step - loss: 0.7381 - accuracy: 0.8032 - val_loss: 0.7605 - val_accuracy: 0.8210
# Epoch 31/60
# 184/184 [==============================] - 16s 86ms/step - loss: 0.7455 - accuracy: 0.8015 - val_loss: 0.6476 - val_accuracy: 0.8387
# Epoch 32/60
# 184/184 [==============================] - 16s 86ms/step - loss: 0.7320 - accuracy: 0.8078 - val_loss: 0.7429 - val_accuracy: 0.8162
# Epoch 33/60
# 184/184 [==============================] - 16s 85ms/step - loss: 0.6986 - accuracy: 0.8226 - val_loss: 0.5868 - val_accuracy: 0.8761
# Epoch 34/60
# 184/184 [==============================] - 16s 84ms/step - loss: 0.7073 - accuracy: 0.8218 - val_loss: 0.6490 - val_accuracy: 0.8530
# Epoch 35/60
# 184/184 [==============================] - 16s 85ms/step - loss: 0.6611 - accuracy: 0.8342 - val_loss: 0.5558 - val_accuracy: 0.8741
# Epoch 36/60
# 184/184 [==============================] - 16s 84ms/step - loss: 0.6922 - accuracy: 0.8216 - val_loss: 0.6084 - val_accuracy: 0.8598
# Epoch 37/60
# 184/184 [==============================] - 16s 85ms/step - loss: 0.6512 - accuracy: 0.8340 - val_loss: 0.6406 - val_accuracy: 0.8448
# Epoch 38/60
# 184/184 [==============================] - 16s 85ms/step - loss: 0.6328 - accuracy: 0.8456 - val_loss: 0.6266 - val_accuracy: 0.8564
# Epoch 39/60
# 184/184 [==============================] - 16s 85ms/step - loss: 0.6316 - accuracy: 0.8436 - val_loss: 0.6386 - val_accuracy: 0.8366
# Epoch 40/60
# 184/184 [==============================] - 16s 86ms/step - loss: 0.6097 - accuracy: 0.8497 - val_loss: 0.9948 - val_accuracy: 0.7236
# Epoch 41/60
# 184/184 [==============================] - 16s 85ms/step - loss: 0.6124 - accuracy: 0.8506 - val_loss: 0.6381 - val_accuracy: 0.8428
# Epoch 42/60
# 184/184 [==============================] - 16s 85ms/step - loss: 0.6395 - accuracy: 0.8419 - val_loss: 0.7640 - val_accuracy: 0.7903
# Epoch 43/60
# 184/184 [==============================] - 16s 85ms/step - loss: 0.6027 - accuracy: 0.8501 - val_loss: 0.6940 - val_accuracy: 0.8182
# Epoch 44/60
# 184/184 [==============================] - 16s 85ms/step - loss: 0.6329 - accuracy: 0.8470 - val_loss: 0.5359 - val_accuracy: 0.8918
# Epoch 45/60
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5807 - accuracy: 0.8620 - val_loss: 0.5461 - val_accuracy: 0.8802
# Epoch 46/60
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5629 - accuracy: 0.8714 - val_loss: 0.5664 - val_accuracy: 0.8693
# Epoch 47/60
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5609 - accuracy: 0.8705 - val_loss: 0.4966 - val_accuracy: 0.9088
# Epoch 48/60
# 184/184 [==============================] - 16s 86ms/step - loss: 0.5441 - accuracy: 0.8709 - val_loss: 0.4790 - val_accuracy: 0.9006
# Epoch 49/60
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5614 - accuracy: 0.8762 - val_loss: 0.7859 - val_accuracy: 0.8053
# Epoch 50/60
# 184/184 [==============================] - 16s 84ms/step - loss: 0.5710 - accuracy: 0.8688 - val_loss: 0.5673 - val_accuracy: 0.8741
# Epoch 51/60
# 184/184 [==============================] - 16s 87ms/step - loss: 0.5983 - accuracy: 0.8615 - val_loss: 0.5831 - val_accuracy: 0.8550
# Epoch 52/60
# 184/184 [==============================] - 16s 87ms/step - loss: 0.5380 - accuracy: 0.8789 - val_loss: 0.4829 - val_accuracy: 0.9047
# Epoch 53/60
# 184/184 [==============================] - 16s 86ms/step - loss: 0.5613 - accuracy: 0.8774 - val_loss: 0.6670 - val_accuracy: 0.8257
# Epoch 54/60
# 184/184 [==============================] - 16s 86ms/step - loss: 0.5204 - accuracy: 0.8873 - val_loss: 0.5342 - val_accuracy: 0.8802
# Epoch 55/60
# 184/184 [==============================] - 16s 87ms/step - loss: 0.5343 - accuracy: 0.8838 - val_loss: 0.4954 - val_accuracy: 0.8986
# Epoch 56/60
# 184/184 [==============================] - 16s 86ms/step - loss: 0.5516 - accuracy: 0.8811 - val_loss: 0.5000 - val_accuracy: 0.9006
# Epoch 57/60
# 184/184 [==============================] - 16s 86ms/step - loss: 0.4959 - accuracy: 0.9047 - val_loss: 0.6810 - val_accuracy: 0.8142
# Epoch 58/60
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5820 - accuracy: 0.8690 - val_loss: 0.5923 - val_accuracy: 0.8536
# Epoch 59/60
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5065 - accuracy: 0.8922 - val_loss: 0.5285 - val_accuracy: 0.8727
# Epoch 60/60
# 184/184 [==============================] - 16s 85ms/step - loss: 0.5247 - accuracy: 0.8896 - val_loss: 0.5425 - val_accuracy: 0.8795

# %%
# Plot accuracy and loss curves
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
# Evaluate model
test_data = r'D:\Project\data_kaggle\test'

eval_generator = train_datagen.flow_from_directory(
    test_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

y_true = eval_generator.classes
y_pred = model.predict(eval_generator)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)  # Fix tf.argmax issue
# Out:
# Found 190 images belonging to 8 classes.

# %%
# Print classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred_classes))

# Plot confusion matrix
conf_mat = confusion_matrix(y_true, y_pred_classes)
class_labels = list(train_generator.class_indices.keys())
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97        28
#            1       0.80      0.57      0.67        21
#            2       0.88      0.84      0.86        25
#            3       0.92      0.52      0.67        23
#            4       0.57      0.95      0.71        21
#            5       0.89      0.70      0.78        23
#            6       0.84      1.00      0.91        26
#            7       0.92      0.96      0.94        23
#
#     accuracy                           0.83       190
#    macro avg       0.84      0.82      0.81       190
# weighted avg       0.85      0.83      0.82       190

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="viridis", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('Actual', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)
plt.show()

# %%
model_version = epochs
next_version = str(int(model_version) + 10)

# %%
import shutil

notebook_filename = f"CNN_{model_version}_ADAM.ipynb"
new_notebook_filename = f"CNN_{next_version}_ADAM.ipynb"

shutil.copy(notebook_filename, new_notebook_filename)
print(f"Notebook copied as {new_notebook_filename}")
# Out:
# Notebook copied as CNN_70_ADAM.ipynb

# %%
os._exit(00)
