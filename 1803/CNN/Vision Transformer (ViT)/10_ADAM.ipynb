# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Define constants
image_size = (224, 224)
patch_size = 16  # Standard ViT patch size
embed_dim = 64  # Embedding dimension
num_heads = 4  # Number of attention heads
transformer_layers = 6  # Number of transformer blocks
mlp_units = [128, 64]  # Feedforward layers in transformer block
mlp_head_units = [256, 128]  # MLP classifier head
num_classes = 10
batch_size = 64
num_patches = (image_size[0] // patch_size) ** 2  # Compute number of patches

# %%
print("TensorFlow version:", tf.__version__)
print("Available GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.6.0
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Dataset paths
train_path = r'D:\Project\data_kaggle\aug\train_split'
val_path = r"D:\Project\data_kaggle\aug\val_split"
test_path = r"D:\Project\data_kaggle\test"

# %%
# Load datasets
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    train_path, seed=42, image_size=image_size, batch_size=batch_size)

val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    val_path, seed=42, image_size=image_size, batch_size=batch_size)
# Out:
# Found 5863 files belonging to 8 classes.
# Found 1469 files belonging to 8 classes.

# %%
# Normalize dataset
normalization_layer = layers.Rescaling(1.0 / 255)
train_dataset = train_dataset.map(lambda x, y: (normalization_layer(x), y))
val_dataset = val_dataset.map(lambda x, y: (normalization_layer(x), y))

# %%
# Data Augmentation
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
])

# %%
# MLP block
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# Vision Transformer Model
def vit_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)

    # Convert image to patches
    patches = layers.Conv2D(embed_dim, kernel_size=patch_size, strides=patch_size, padding="valid")(inputs)
    patches = layers.Reshape((num_patches, embed_dim))(patches)

    # Add trainable class token ([CLS] token)
    cls_token = tf.Variable(tf.zeros((1, 1, embed_dim)), trainable=True)
    cls_tokens = tf.tile(cls_token, [tf.shape(patches)[0], 1, 1])
    x = tf.concat([cls_tokens, patches], axis=1)  # Prepend CLS token

    # Positional Embeddings
    positions = tf.range(start=0, limit=num_patches + 1, delta=1)
    pos_embedding = layers.Embedding(input_dim=num_patches + 1, output_dim=embed_dim)(positions)
    x = x + pos_embedding

    # Transformer blocks
    for _ in range(transformer_layers):
        x_norm = layers.LayerNormalization(epsilon=1e-6)(x)
        attention_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim // num_heads)(x_norm, x_norm)
        x = layers.Add()([x, attention_output])  # Residual Connection

        x_norm = layers.LayerNormalization(epsilon=1e-6)(x)
        mlp_output = mlp(x_norm, hidden_units=mlp_units, dropout_rate=0.1)
        x = layers.Add()([x, mlp_output])  # Residual Connection

    # Use CLS token for classification
    x = layers.LayerNormalization(epsilon=1e-6)(x[:, 0, :])  # Extract CLS token
    x = layers.Dropout(0.5)(x)
    x = mlp(x, hidden_units=mlp_head_units, dropout_rate=0.5)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return models.Model(inputs, outputs)

# Create ViT model
vit_classifier = vit_model((image_size[0], image_size[1], 3), num_classes)
vit_classifier.summary()
# Out:
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.tile), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(1, 1, 64) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 14, 14, 64)   49216       input_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 196, 64)      0           conv2d[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape (TFOpLambda) (3,)                 0           reshape[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici ()                   0           tf.compat.v1.shape[0][0]
# __________________________________________________________________________________________________
# tf.tile (TFOpLambda)            (None, 1, 64)        0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, 197, 64)      0           tf.tile[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 197, 64)      0           tf.concat[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 197, 64)      128         tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# multi_head_attention (MultiHead (None, 197, 64)      16640       layer_normalization[0][0]
#                                                                  layer_normalization[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 197, 64)      0           tf.__operators__.add[0][0]
#                                                                  multi_head_attention[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 197, 64)      128         add[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 197, 128)     8320        layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 197, 128)     0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 197, 64)      8256        dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 197, 64)      0           dense_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 197, 64)      0           add[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 197, 64)      128         add_1[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_1 (MultiHe (None, 197, 64)      16640       layer_normalization_2[0][0]
#                                                                  layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 197, 64)      0           add_1[0][0]
#                                                                  multi_head_attention_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 197, 64)      128         add_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 197, 128)     8320        layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 197, 128)     0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 197, 64)      8256        dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 197, 64)      0           dense_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 197, 64)      0           add_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 197, 64)      128         add_3[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_2 (MultiHe (None, 197, 64)      16640       layer_normalization_4[0][0]
#                                                                  layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 197, 64)      0           add_3[0][0]
#                                                                  multi_head_attention_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 197, 64)      128         add_4[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 197, 128)     8320        layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 197, 128)     0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 197, 64)      8256        dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 197, 64)      0           dense_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 197, 64)      0           add_4[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 197, 64)      128         add_5[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_3 (MultiHe (None, 197, 64)      16640       layer_normalization_6[0][0]
#                                                                  layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 197, 64)      0           add_5[0][0]
#                                                                  multi_head_attention_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 197, 64)      128         add_6[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 197, 128)     8320        layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 197, 128)     0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 197, 64)      8256        dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 197, 64)      0           dense_7[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 197, 64)      0           add_6[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 197, 64)      128         add_7[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_4 (MultiHe (None, 197, 64)      16640       layer_normalization_8[0][0]
#                                                                  layer_normalization_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 197, 64)      0           add_7[0][0]
#                                                                  multi_head_attention_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization_9 (LayerNor (None, 197, 64)      128         add_8[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 197, 128)     8320        layer_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 197, 128)     0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 197, 64)      8256        dropout_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 197, 64)      0           dense_9[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 197, 64)      0           add_8[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# layer_normalization_10 (LayerNo (None, 197, 64)      128         add_9[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_5 (MultiHe (None, 197, 64)      16640       layer_normalization_10[0][0]
#                                                                  layer_normalization_10[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 197, 64)      0           add_9[0][0]
#                                                                  multi_head_attention_5[0][0]
# __________________________________________________________________________________________________
# layer_normalization_11 (LayerNo (None, 197, 64)      128         add_10[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 197, 128)     8320        layer_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 197, 128)     0           dense_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 197, 64)      8256        dropout_10[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 197, 64)      0           dense_11[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 197, 64)      0           add_10[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1 (Sli (None, 64)           0           add_11[0][0]
# __________________________________________________________________________________________________
# layer_normalization_12 (LayerNo (None, 64)           128         tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 64)           0           layer_normalization_12[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 256)          16640       dropout_12[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 256)          0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 128)          32896       dropout_13[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 128)          0           dense_13[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 10)           1290        dropout_14[0][0]
# ==================================================================================================
# Total params: 301,002
# Trainable params: 301,002
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Training function
def run_experiment(model, train_data, val_data, num_epochs=10):
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
        metrics=["accuracy"]
    )

    history = model.fit(train_data, validation_data=val_data, epochs=num_epochs)
    return history

# Train Model
num_epochs = int(input("Enter number of epochs: "))
history = run_experiment(vit_classifier, train_dataset, val_dataset, num_epochs)
# Out:
# Enter number of epochs:  10
# Epoch 1/10
# 92/92 [==============================] - 61s 346ms/step - loss: 2.4553 - accuracy: 0.1230 - val_loss: 2.1532 - val_accuracy: 0.2090
# Epoch 2/10
# 92/92 [==============================] - 31s 325ms/step - loss: 2.2983 - accuracy: 0.1457 - val_loss: 2.1301 - val_accuracy: 0.2015
# Epoch 3/10
# 92/92 [==============================] - 31s 323ms/step - loss: 2.2456 - accuracy: 0.1429 - val_loss: 2.1140 - val_accuracy: 0.1954
# Epoch 4/10
# 92/92 [==============================] - 31s 326ms/step - loss: 2.2194 - accuracy: 0.1441 - val_loss: 2.1145 - val_accuracy: 0.1947
# Epoch 5/10
# 92/92 [==============================] - 32s 328ms/step - loss: 2.1987 - accuracy: 0.1516 - val_loss: 2.0979 - val_accuracy: 0.1981
# Epoch 6/10
# 92/92 [==============================] - 31s 326ms/step - loss: 2.1848 - accuracy: 0.1578 - val_loss: 2.0901 - val_accuracy: 0.1995
# Epoch 7/10
# 92/92 [==============================] - 32s 330ms/step - loss: 2.1742 - accuracy: 0.1576 - val_loss: 2.0805 - val_accuracy: 0.1981
# Epoch 8/10
# 92/92 [==============================] - 33s 338ms/step - loss: 2.1472 - accuracy: 0.1665 - val_loss: 2.0727 - val_accuracy: 0.2199
# Epoch 9/10
# 92/92 [==============================] - 32s 330ms/step - loss: 2.1392 - accuracy: 0.1671 - val_loss: 2.0456 - val_accuracy: 0.2369
# Epoch 10/10
# 92/92 [==============================] - 32s 330ms/step - loss: 2.1076 - accuracy: 0.1825 - val_loss: 2.0142 - val_accuracy: 0.2389

# %%
# Plot Training History
def plot_history(history, metric):
    plt.plot(history.history[metric], label=metric)
    plt.plot(history.history["val_" + metric], label="val_" + metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend()
    plt.grid()
    plt.show()

plot_history(history, "loss")
plot_history(history, "accuracy")

# %%
# Evaluate Model
_, test_accuracy = vit_classifier.evaluate(val_dataset)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# 23/23 [==============================] - 5s 166ms/step - loss: 2.0142 - accuracy: 0.2389
# Test accuracy: 23.89%

# %%
# Load Test Data
test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    test_path, seed=42, image_size=image_size, batch_size=batch_size)
# Out:
# Found 190 files belonging to 8 classes.

# %%
# Predictions
y_true = np.concatenate([y for _, y in test_dataset], axis=0)
y_pred = np.argmax(vit_classifier.predict(test_dataset), axis=1)

# %%
# Print Classification Report
print("\nClassification Report:\n", classification_report(y_true, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        28
#            1       0.00      0.00      0.00        21
#            2       0.50      0.04      0.07        25
#            3       0.00      0.00      0.00        23
#            4       0.00      0.00      0.00        21
#            5       0.40      0.09      0.14        23
#            6       0.14      1.00      0.25        26
#            7       0.00      0.00      0.00        23
#
#     accuracy                           0.15       190
#    macro avg       0.13      0.14      0.06       190
# weighted avg       0.13      0.15      0.06       190
# C:\Users\mohan\anaconda3\envs\gpu\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohan\anaconda3\envs\gpu\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohan\anaconda3\envs\gpu\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Load datasets again to get class names
raw_train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    train_path, seed=42, image_size=image_size, batch_size=batch_size)

# Extract class names correctly
class_labels = raw_train_dataset.class_names

# Confusion Matrix
conf_mat = confusion_matrix(y_true, y_pred)
class_labels = raw_train_dataset.class_names
# Out:
# Found 5863 files belonging to 8 classes.

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="viridis", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
model_version = num_epochs
next_version = str(int(model_version) + 10)

import shutil

notebook_filename = f"{model_version}_ADAM.ipynb"
new_notebook_filename = f"{next_version}_ADAM.ipynb"

shutil.copy(notebook_filename, new_notebook_filename)
print(f"Notebook copied as {new_notebook_filename}")

# %%
import os
os._exit(00)
