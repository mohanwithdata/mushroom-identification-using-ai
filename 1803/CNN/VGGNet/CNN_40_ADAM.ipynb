# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Input
import os

# %%
print(tf.config.list_physical_devices('GPU'))
print(len(tf.config.list_physical_devices('GPU')))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 1

# %%
# Set dataset path
data_dir = r'D:\Project\data_kaggle\aug\train_split'

# %%
batch_size = 32
img_height = 224
img_width = 224
image_size = (img_height, img_width)
epochs = int(input("Enter epochs number: "))
# Out:
# Enter epochs number:  40

# %%
train_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb'  # Force RGB mode
)
# Out:
# Found 5863 images belonging to 8 classes.

# %%
val_datagen = ImageDataGenerator()

val_data = r"D:\Project\data_kaggle\aug\val_split"

val_generator = val_datagen.flow_from_directory(
    val_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
)
# Out:
# Found 1469 images belonging to 8 classes.

# %%
base_model = VGG16(weights=None, include_top=False, input_shape=(224, 224, 3))

# Freeze convolutional base (optional)
for layer in base_model.layers:
    layer.trainable = False

# Add new classifier head
x = base_model.output
x = GlobalAveragePooling2D()(x)  # Flatten feature maps
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
output_layer = Dense(8, activation='softmax')(x)  # Output layer with 8 classes

# Create the final model
model = Model(inputs=base_model.input, outputs=output_layer)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 15,110,728
# Trainable params: 396,040
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)
# Out:
# Epoch 1/40
# 184/184 [==============================] - 77s 339ms/step - loss: 2.0788 - accuracy: 0.1721 - val_loss: 2.0403 - val_accuracy: 0.1947
# Epoch 2/40
# 184/184 [==============================] - 45s 240ms/step - loss: 2.0400 - accuracy: 0.1905 - val_loss: 2.0312 - val_accuracy: 0.1947
# Epoch 3/40
# 184/184 [==============================] - 47s 252ms/step - loss: 2.0366 - accuracy: 0.1946 - val_loss: 2.0318 - val_accuracy: 0.1947
# Epoch 4/40
# 184/184 [==============================] - 47s 256ms/step - loss: 2.0359 - accuracy: 0.1944 - val_loss: 2.0348 - val_accuracy: 0.1947
# Epoch 5/40
# 184/184 [==============================] - 44s 239ms/step - loss: 2.0287 - accuracy: 0.1948 - val_loss: 2.0195 - val_accuracy: 0.1947
# Epoch 6/40
# 184/184 [==============================] - 44s 239ms/step - loss: 2.0237 - accuracy: 0.1948 - val_loss: 2.0171 - val_accuracy: 0.1947
# Epoch 7/40
# 184/184 [==============================] - 44s 239ms/step - loss: 2.0330 - accuracy: 0.1950 - val_loss: 2.0377 - val_accuracy: 0.1947
# Epoch 8/40
# 184/184 [==============================] - 44s 239ms/step - loss: 2.0376 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 9/40
# 184/184 [==============================] - 44s 240ms/step - loss: 2.0388 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 10/40
# 184/184 [==============================] - 46s 247ms/step - loss: 2.0393 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 11/40
# 184/184 [==============================] - 56s 305ms/step - loss: 2.0380 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 12/40
# 184/184 [==============================] - 50s 267ms/step - loss: 2.0380 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 13/40
# 184/184 [==============================] - 62s 338ms/step - loss: 2.0395 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 14/40
# 184/184 [==============================] - 66s 357ms/step - loss: 2.0390 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 15/40
# 184/184 [==============================] - 65s 351ms/step - loss: 2.0384 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 16/40
# 184/184 [==============================] - 61s 331ms/step - loss: 2.0383 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 17/40
# 184/184 [==============================] - 57s 308ms/step - loss: 2.0390 - accuracy: 0.1948 - val_loss: 2.0372 - val_accuracy: 0.1947
# Epoch 18/40
# 184/184 [==============================] - 65s 354ms/step - loss: 2.0384 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 19/40
# 184/184 [==============================] - 55s 297ms/step - loss: 2.0382 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 20/40
# 184/184 [==============================] - 55s 299ms/step - loss: 2.0384 - accuracy: 0.1948 - val_loss: 2.0370 - val_accuracy: 0.1947
# Epoch 21/40
# 184/184 [==============================] - 51s 276ms/step - loss: 2.0387 - accuracy: 0.1948 - val_loss: 2.0372 - val_accuracy: 0.1947
# Epoch 22/40
# 184/184 [==============================] - 56s 301ms/step - loss: 2.0380 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 23/40
# 184/184 [==============================] - 59s 320ms/step - loss: 2.0379 - accuracy: 0.1948 - val_loss: 2.0372 - val_accuracy: 0.1947
# Epoch 24/40
# 184/184 [==============================] - 64s 345ms/step - loss: 2.0380 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 25/40
# 184/184 [==============================] - 52s 283ms/step - loss: 2.0372 - accuracy: 0.1948 - val_loss: 2.0372 - val_accuracy: 0.1947
# Epoch 26/40
# 184/184 [==============================] - 64s 344ms/step - loss: 2.0380 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 27/40
# 184/184 [==============================] - 53s 285ms/step - loss: 2.0375 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 28/40
# 184/184 [==============================] - 62s 335ms/step - loss: 2.0386 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 29/40
# 184/184 [==============================] - 75s 408ms/step - loss: 2.0377 - accuracy: 0.1948 - val_loss: 2.0370 - val_accuracy: 0.1947
# Epoch 30/40
# 184/184 [==============================] - 76s 409ms/step - loss: 2.0381 - accuracy: 0.1948 - val_loss: 2.0373 - val_accuracy: 0.1947
# Epoch 31/40
# 184/184 [==============================] - 77s 416ms/step - loss: 2.0386 - accuracy: 0.1948 - val_loss: 2.0372 - val_accuracy: 0.1947
# Epoch 32/40
# 184/184 [==============================] - 78s 421ms/step - loss: 2.0386 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 33/40
# 184/184 [==============================] - 79s 430ms/step - loss: 2.0378 - accuracy: 0.1948 - val_loss: 2.0370 - val_accuracy: 0.1947
# Epoch 34/40
# 184/184 [==============================] - 73s 396ms/step - loss: 2.0375 - accuracy: 0.1948 - val_loss: 2.0370 - val_accuracy: 0.1947
# Epoch 35/40
# 184/184 [==============================] - 80s 431ms/step - loss: 2.0379 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947
# Epoch 36/40
# 184/184 [==============================] - 60s 325ms/step - loss: 2.0383 - accuracy: 0.1948 - val_loss: 2.0370 - val_accuracy: 0.1947
# Epoch 37/40
# 184/184 [==============================] - 60s 325ms/step - loss: 2.0377 - accuracy: 0.1948 - val_loss: 2.0370 - val_accuracy: 0.1947
# Epoch 38/40
# 184/184 [==============================] - 52s 281ms/step - loss: 2.0378 - accuracy: 0.1948 - val_loss: 2.0370 - val_accuracy: 0.1947
# Epoch 39/40
# 184/184 [==============================] - 51s 273ms/step - loss: 2.0379 - accuracy: 0.1948 - val_loss: 2.0370 - val_accuracy: 0.1947
# Epoch 40/40
# 184/184 [==============================] - 50s 271ms/step - loss: 2.0379 - accuracy: 0.1948 - val_loss: 2.0371 - val_accuracy: 0.1947

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
# Evaluate model
test_data = r'D:\Project\data_kaggle\test'

eval_generator = train_datagen.flow_from_directory(
    test_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

y_true = eval_generator.classes
y_pred = model.predict(eval_generator)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)  # Fix tf.argmax issue
# Out:
# Found 190 images belonging to 8 classes.

# %%
# Print classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred_classes))

# Plot confusion matrix
conf_mat = confusion_matrix(y_true, y_pred_classes)
class_labels = list(train_generator.class_indices.keys())
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        28
#            1       0.00      0.00      0.00        21
#            2       0.00      0.00      0.00        25
#            3       0.00      0.00      0.00        23
#            4       0.00      0.00      0.00        21
#            5       0.00      0.00      0.00        23
#            6       0.14      1.00      0.24        26
#            7       0.00      0.00      0.00        23
#
#     accuracy                           0.14       190
#    macro avg       0.02      0.12      0.03       190
# weighted avg       0.02      0.14      0.03       190
# C:\Users\mohan\anaconda3\envs\gpu\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohan\anaconda3\envs\gpu\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohan\anaconda3\envs\gpu\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="viridis", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('Actual', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)
plt.show()

# %%
model_version = epochs
next_version = str(int(model_version) + 10)

# %%
import shutil

notebook_filename = f"CNN_{model_version}_ADAM.ipynb"
new_notebook_filename = f"CNN_{next_version}_ADAM.ipynb"

shutil.copy(notebook_filename, new_notebook_filename)
print(f"Notebook copied as {new_notebook_filename}")
# Out:
# Notebook copied as CNN_50_ADAM.ipynb

# %%
os._exit(00)
