# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Input
import os

# %%
print(tf.config.list_physical_devices('GPU'))
print(len(tf.config.list_physical_devices('GPU')))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 1

# %%
# Set dataset path
data_dir = r'D:\Project\data_kaggle\aug\train_split'

# %%
batch_size = 32
img_height = 224
img_width = 224
image_size = (img_height, img_width)
epochs = int(input("Enter epochs number: "))
# Out:
# Enter epochs number:  30

# %%
train_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb'  # Force RGB mode
)
# Out:
# Found 5863 images belonging to 8 classes.

# %%
val_datagen = ImageDataGenerator()

val_data = r"D:\Project\data_kaggle\aug\val_split"

val_generator = val_datagen.flow_from_directory(
    val_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
)
# Out:
# Found 1469 images belonging to 8 classes.

# %%
base_model = VGG16(weights=None, include_top=False, input_shape=(224, 224, 3))

# Freeze convolutional base (optional)
for layer in base_model.layers:
    layer.trainable = False

# Add new classifier head
x = base_model.output
x = GlobalAveragePooling2D()(x)  # Flatten feature maps
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
output_layer = Dense(8, activation='softmax')(x)  # Output layer with 8 classes

# Create the final model
model = Model(inputs=base_model.input, outputs=output_layer)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 15,110,728
# Trainable params: 396,040
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)
# Out:
# Epoch 1/30
# 184/184 [==============================] - 66s 278ms/step - loss: 2.0649 - accuracy: 0.1689 - val_loss: 2.0419 - val_accuracy: 0.1947
# Epoch 2/30
# 184/184 [==============================] - 46s 251ms/step - loss: 2.0408 - accuracy: 0.1868 - val_loss: 2.0297 - val_accuracy: 0.1947
# Epoch 3/30
# 184/184 [==============================] - 46s 247ms/step - loss: 2.0323 - accuracy: 0.1968 - val_loss: 2.0240 - val_accuracy: 0.1947
# Epoch 4/30
# 184/184 [==============================] - 46s 247ms/step - loss: 2.0344 - accuracy: 0.1970 - val_loss: 2.0199 - val_accuracy: 0.1947
# Epoch 5/30
# 184/184 [==============================] - 46s 247ms/step - loss: 2.0251 - accuracy: 0.1963 - val_loss: 2.0300 - val_accuracy: 0.1947
# Epoch 6/30
# 184/184 [==============================] - 46s 248ms/step - loss: 2.0144 - accuracy: 0.2060 - val_loss: 2.0079 - val_accuracy: 0.2056
# Epoch 7/30
# 184/184 [==============================] - 46s 246ms/step - loss: 1.9969 - accuracy: 0.2134 - val_loss: 1.9818 - val_accuracy: 0.2131
# Epoch 8/30
# 184/184 [==============================] - 47s 256ms/step - loss: 1.9881 - accuracy: 0.2181 - val_loss: 1.9709 - val_accuracy: 0.2199
# Epoch 9/30
# 184/184 [==============================] - 46s 248ms/step - loss: 1.9808 - accuracy: 0.2175 - val_loss: 1.9546 - val_accuracy: 0.2314
# Epoch 10/30
# 184/184 [==============================] - 47s 253ms/step - loss: 1.9702 - accuracy: 0.2192 - val_loss: 1.9205 - val_accuracy: 0.2437
# Epoch 11/30
# 184/184 [==============================] - 46s 248ms/step - loss: 1.9584 - accuracy: 0.2294 - val_loss: 1.8801 - val_accuracy: 0.3009
# Epoch 12/30
# 184/184 [==============================] - 46s 247ms/step - loss: 1.9584 - accuracy: 0.2308 - val_loss: 1.9156 - val_accuracy: 0.2471
# Epoch 13/30
# 184/184 [==============================] - 46s 247ms/step - loss: 1.9606 - accuracy: 0.2289 - val_loss: 1.9232 - val_accuracy: 0.2464
# Epoch 14/30
# 184/184 [==============================] - 46s 247ms/step - loss: 1.9496 - accuracy: 0.2362 - val_loss: 1.8827 - val_accuracy: 0.2634
# Epoch 15/30
# 184/184 [==============================] - 45s 241ms/step - loss: 1.9536 - accuracy: 0.2311 - val_loss: 1.9145 - val_accuracy: 0.2451
# Epoch 16/30
# 184/184 [==============================] - 46s 249ms/step - loss: 1.9484 - accuracy: 0.2415 - val_loss: 1.9281 - val_accuracy: 0.2457
# Epoch 17/30
# 184/184 [==============================] - 45s 243ms/step - loss: 1.9435 - accuracy: 0.2384 - val_loss: 1.9371 - val_accuracy: 0.2253
# Epoch 18/30
# 184/184 [==============================] - 46s 251ms/step - loss: 1.9410 - accuracy: 0.2405 - val_loss: 1.9026 - val_accuracy: 0.2512
# Epoch 19/30
# 184/184 [==============================] - 46s 248ms/step - loss: 1.9396 - accuracy: 0.2400 - val_loss: 1.8688 - val_accuracy: 0.2771
# Epoch 20/30
# 184/184 [==============================] - 46s 247ms/step - loss: 1.9457 - accuracy: 0.2396 - val_loss: 1.9161 - val_accuracy: 0.2485
# Epoch 21/30
# 184/184 [==============================] - 47s 254ms/step - loss: 1.9378 - accuracy: 0.2427 - val_loss: 1.9136 - val_accuracy: 0.2464
# Epoch 22/30
# 184/184 [==============================] - 46s 248ms/step - loss: 1.9272 - accuracy: 0.2458 - val_loss: 1.8376 - val_accuracy: 0.2954
# Epoch 23/30
# 184/184 [==============================] - 46s 247ms/step - loss: 1.9399 - accuracy: 0.2391 - val_loss: 1.9099 - val_accuracy: 0.2444
# Epoch 24/30
# 184/184 [==============================] - 46s 251ms/step - loss: 1.9481 - accuracy: 0.2398 - val_loss: 1.8560 - val_accuracy: 0.2886
# Epoch 25/30
# 184/184 [==============================] - 46s 247ms/step - loss: 1.9288 - accuracy: 0.2480 - val_loss: 1.9149 - val_accuracy: 0.2430
# Epoch 26/30
# 184/184 [==============================] - 46s 247ms/step - loss: 1.9216 - accuracy: 0.2449 - val_loss: 1.8396 - val_accuracy: 0.2907
# Epoch 27/30
# 184/184 [==============================] - 46s 247ms/step - loss: 1.9224 - accuracy: 0.2512 - val_loss: 1.8330 - val_accuracy: 0.2893
# Epoch 28/30
# 184/184 [==============================] - 45s 245ms/step - loss: 1.9188 - accuracy: 0.2553 - val_loss: 1.8961 - val_accuracy: 0.2573
# Epoch 29/30
# 184/184 [==============================] - 48s 260ms/step - loss: 1.9334 - accuracy: 0.2432 - val_loss: 1.9605 - val_accuracy: 0.2294
# Epoch 30/30
# 184/184 [==============================] - 47s 256ms/step - loss: 1.9281 - accuracy: 0.2412 - val_loss: 1.8785 - val_accuracy: 0.2614

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
# Evaluate model
test_data = r'D:\Project\data_kaggle\test'

eval_generator = train_datagen.flow_from_directory(
    test_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

y_true = eval_generator.classes
y_pred = model.predict(eval_generator)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)  # Fix tf.argmax issue
# Out:
# Found 190 images belonging to 8 classes.

# %%
# Print classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred_classes))

# Plot confusion matrix
conf_mat = confusion_matrix(y_true, y_pred_classes)
class_labels = list(train_generator.class_indices.keys())
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.54      0.64        28
#            1       0.00      0.00      0.00        21
#            2       0.39      0.36      0.38        25
#            3       0.67      0.09      0.15        23
#            4       0.00      0.00      0.00        21
#            5       1.00      0.04      0.08        23
#            6       0.16      0.88      0.27        26
#            7       0.00      0.00      0.00        23
#
#     accuracy                           0.26       190
#    macro avg       0.38      0.24      0.19       190
# weighted avg       0.39      0.26      0.21       190
# C:\Users\mohan\anaconda3\envs\gpu\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohan\anaconda3\envs\gpu\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohan\anaconda3\envs\gpu\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="viridis", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('Actual', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)
plt.show()

# %%
model_version = epochs
next_version = str(int(model_version) + 10)

# %%
import shutil

notebook_filename = f"CNN_{model_version}_ADAM.ipynb"
new_notebook_filename = f"CNN_{next_version}_ADAM.ipynb"

shutil.copy(notebook_filename, new_notebook_filename)
print(f"Notebook copied as {new_notebook_filename}")
# Out:
# Notebook copied as CNN_40_ADAM.ipynb

# %%
os._exit(00)
