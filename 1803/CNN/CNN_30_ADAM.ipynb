# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Input
import os

# %%
# Set dataset path
data_dir = r'D:\Project\data_kaggle\train'

# %%
batch_size = 32
img_height = 224
img_width = 224
image_size = (img_height, img_width)
epochs = int(input("Enter epochs number: "))
# Out:
# Enter epochs number:  30

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb'  # Force RGB mode
)
# Out:
# Found 1833 images belonging to 8 classes.

# %%
val_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 364 images belonging to 8 classes.

# %%
model = Sequential([
    Input(shape=(224, 224, 3)),  # Define input explicitly
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(256, activation='relu'),
    Dense(len(train_generator.class_indices), activation='softmax')  # Output layer
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 86528)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               22151424
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 22,246,728
# Trainable params: 22,246,728
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)
# Out:
# Epoch 1/30
# 58/58 [==============================] - 32s 297ms/step - loss: 1.7737 - accuracy: 0.3541 - val_loss: 1.3773 - val_accuracy: 0.4780
# Epoch 2/30
# 58/58 [==============================] - 14s 243ms/step - loss: 1.1039 - accuracy: 0.6110 - val_loss: 0.8940 - val_accuracy: 0.6978
# Epoch 3/30
# 58/58 [==============================] - 14s 243ms/step - loss: 0.7088 - accuracy: 0.7529 - val_loss: 0.5952 - val_accuracy: 0.7940
# Epoch 4/30
# 58/58 [==============================] - 15s 250ms/step - loss: 0.3835 - accuracy: 0.8674 - val_loss: 0.1522 - val_accuracy: 0.9560
# Epoch 5/30
# 58/58 [==============================] - 15s 251ms/step - loss: 0.1471 - accuracy: 0.9514 - val_loss: 0.1023 - val_accuracy: 0.9780
# Epoch 6/30
# 58/58 [==============================] - 14s 244ms/step - loss: 0.1115 - accuracy: 0.9640 - val_loss: 0.0303 - val_accuracy: 0.9945
# Epoch 7/30
# 58/58 [==============================] - 14s 244ms/step - loss: 0.0303 - accuracy: 0.9907 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 8/30
# 58/58 [==============================] - 15s 248ms/step - loss: 0.0189 - accuracy: 0.9951 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 9/30
# 58/58 [==============================] - 14s 243ms/step - loss: 0.0190 - accuracy: 0.9956 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 10/30
# 58/58 [==============================] - 14s 245ms/step - loss: 0.0129 - accuracy: 0.9967 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 11/30
# 58/58 [==============================] - 14s 245ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 12/30
# 58/58 [==============================] - 14s 245ms/step - loss: 4.9398e-04 - accuracy: 1.0000 - val_loss: 2.6441e-04 - val_accuracy: 1.0000
# Epoch 13/30
# 58/58 [==============================] - 14s 245ms/step - loss: 2.2224e-04 - accuracy: 1.0000 - val_loss: 1.9655e-04 - val_accuracy: 1.0000
# Epoch 14/30
# 58/58 [==============================] - 14s 244ms/step - loss: 1.5756e-04 - accuracy: 1.0000 - val_loss: 1.5498e-04 - val_accuracy: 1.0000
# Epoch 15/30
# 58/58 [==============================] - 15s 250ms/step - loss: 1.2446e-04 - accuracy: 1.0000 - val_loss: 1.2573e-04 - val_accuracy: 1.0000
# Epoch 16/30
# 58/58 [==============================] - 14s 243ms/step - loss: 1.0353e-04 - accuracy: 1.0000 - val_loss: 1.0842e-04 - val_accuracy: 1.0000
# Epoch 17/30
# 58/58 [==============================] - 15s 246ms/step - loss: 8.9111e-05 - accuracy: 1.0000 - val_loss: 9.0940e-05 - val_accuracy: 1.0000
# Epoch 18/30
# 58/58 [==============================] - 15s 249ms/step - loss: 7.7165e-05 - accuracy: 1.0000 - val_loss: 7.9639e-05 - val_accuracy: 1.0000
# Epoch 19/30
# 58/58 [==============================] - 14s 248ms/step - loss: 6.7692e-05 - accuracy: 1.0000 - val_loss: 6.9045e-05 - val_accuracy: 1.0000
# Epoch 20/30
# 58/58 [==============================] - 16s 271ms/step - loss: 6.0000e-05 - accuracy: 1.0000 - val_loss: 6.0557e-05 - val_accuracy: 1.0000
# Epoch 21/30
# 58/58 [==============================] - 15s 246ms/step - loss: 5.3270e-05 - accuracy: 1.0000 - val_loss: 5.4621e-05 - val_accuracy: 1.0000
# Epoch 22/30
# 58/58 [==============================] - 14s 243ms/step - loss: 4.7461e-05 - accuracy: 1.0000 - val_loss: 4.6915e-05 - val_accuracy: 1.0000
# Epoch 23/30
# 58/58 [==============================] - 15s 251ms/step - loss: 4.2201e-05 - accuracy: 1.0000 - val_loss: 4.0992e-05 - val_accuracy: 1.0000
# Epoch 24/30
# 58/58 [==============================] - 14s 243ms/step - loss: 3.7060e-05 - accuracy: 1.0000 - val_loss: 3.4769e-05 - val_accuracy: 1.0000
# Epoch 25/30
# 58/58 [==============================] - 14s 243ms/step - loss: 3.2078e-05 - accuracy: 1.0000 - val_loss: 2.9950e-05 - val_accuracy: 1.0000
# Epoch 26/30
# 58/58 [==============================] - 15s 244ms/step - loss: 2.7547e-05 - accuracy: 1.0000 - val_loss: 2.4408e-05 - val_accuracy: 1.0000
# Epoch 27/30
# 58/58 [==============================] - 14s 243ms/step - loss: 2.3525e-05 - accuracy: 1.0000 - val_loss: 2.0954e-05 - val_accuracy: 1.0000
# Epoch 28/30
# 58/58 [==============================] - 14s 241ms/step - loss: 2.0160e-05 - accuracy: 1.0000 - val_loss: 1.7372e-05 - val_accuracy: 1.0000
# Epoch 29/30
# 58/58 [==============================] - 14s 244ms/step - loss: 1.7005e-05 - accuracy: 1.0000 - val_loss: 1.4081e-05 - val_accuracy: 1.0000
# Epoch 30/30
# 58/58 [==============================] - 14s 242ms/step - loss: 1.4318e-05 - accuracy: 1.0000 - val_loss: 1.2656e-05 - val_accuracy: 1.0000

# %%
# Plot accuracy and loss curves
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
# Evaluate model
test_data = r'D:\Project\data_kaggle\test'

eval_generator = train_datagen.flow_from_directory(
    test_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

y_true = eval_generator.classes
y_pred = model.predict(eval_generator)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)  # Fix tf.argmax issue
# Out:
# Found 190 images belonging to 8 classes.

# %%
# Print classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred_classes))

# Plot confusion matrix
conf_mat = confusion_matrix(y_true, y_pred_classes)
class_labels = list(train_generator.class_indices.keys())
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        28
#            1       0.72      0.86      0.78        21
#            2       0.92      0.92      0.92        25
#            3       0.90      0.83      0.86        23
#            4       0.65      0.62      0.63        21
#            5       0.64      0.70      0.67        23
#            6       0.79      0.85      0.81        26
#            7       0.83      0.65      0.73        23
#
#     accuracy                           0.81       190
#    macro avg       0.81      0.80      0.80       190
# weighted avg       0.82      0.81      0.81       190

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="viridis", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('Actual', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)
plt.show()

# %%
model_version = epochs
next_version = str(int(model_version) + 10)

# %%
import shutil

notebook_filename = f"CNN_{model_version}_ADAM.ipynb"
new_notebook_filename = f"CNN_{next_version}_ADAM.ipynb"

shutil.copy(notebook_filename, new_notebook_filename)
print(f"Notebook copied as {new_notebook_filename}")
# Out:
# Notebook copied as CNN_40_ADAM.ipynb

# %%
os._exit(00)
