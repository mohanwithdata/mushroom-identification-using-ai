# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.regularizers import l2
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Input
import os

# %%
# Set dataset path
data_dir = r'D:\Project\data_kaggle\aug\train_split'

# %%
batch_size = 32
img_height = 224
img_width = 224
image_size = (img_height, img_width)
epochs = int(input("Enter epochs number: "))
# Out:
# Enter epochs number:  20

# %%
train_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb'  # Force RGB mode
)
# Out:
# Found 5863 images belonging to 8 classes.

# %%
val_datagen = ImageDataGenerator()

val_data = r"D:\Project\data_kaggle\aug\val_split"

val_generator = val_datagen.flow_from_directory(
    val_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
)
# Out:
# Found 1469 images belonging to 8 classes.

# %%
model = Sequential([
    Input(shape=(224, 224, 3)),  # Explicit input shape

    # First Conv Block
    Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.001)),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.3),  # Drop 30% of neurons

    # Second Conv Block
    Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.001)),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.4),  # Drop 40% of neurons

    # Third Conv Block
    Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.001)),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.5),  # Drop 50% of neurons

    # Fully Connected Layers
    Flatten(),
    Dense(256, activation='relu', kernel_regularizer=l2(0.001)),  # L2 regularization
    Dropout(0.5),  # Strong dropout to prevent overfitting
    Dense(len(train_generator.class_indices), activation='softmax')  # Output layer
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 86528)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               22151424
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 22,246,728
# Trainable params: 22,246,728
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)
# Out:
# Epoch 1/20
# 184/184 [==============================] - 44s 183ms/step - loss: 33.3203 - accuracy: 0.1648 - val_loss: 3.2585 - val_accuracy: 0.1947
# Epoch 2/20
# 184/184 [==============================] - 36s 195ms/step - loss: 3.2366 - accuracy: 0.1861 - val_loss: 3.2052 - val_accuracy: 0.1947
# Epoch 3/20
# 184/184 [==============================] - 35s 190ms/step - loss: 3.1839 - accuracy: 0.1902 - val_loss: 3.1575 - val_accuracy: 0.1947
# Epoch 4/20
# 184/184 [==============================] - 33s 179ms/step - loss: 3.1355 - accuracy: 0.1924 - val_loss: 3.1030 - val_accuracy: 0.1954
# Epoch 5/20
# 184/184 [==============================] - 32s 174ms/step - loss: 3.0864 - accuracy: 0.1948 - val_loss: 3.0712 - val_accuracy: 0.1974
# Epoch 6/20
# 184/184 [==============================] - 37s 201ms/step - loss: 3.0461 - accuracy: 0.1946 - val_loss: 3.0263 - val_accuracy: 0.2015
# Epoch 7/20
# 184/184 [==============================] - 35s 187ms/step - loss: 2.9946 - accuracy: 0.1968 - val_loss: 2.9800 - val_accuracy: 0.1967
# Epoch 8/20
# 184/184 [==============================] - 34s 184ms/step - loss: 2.9542 - accuracy: 0.2004 - val_loss: 2.9358 - val_accuracy: 0.2029
# Epoch 9/20
# 184/184 [==============================] - 37s 202ms/step - loss: 2.9082 - accuracy: 0.2076 - val_loss: 2.9053 - val_accuracy: 0.2056
# Epoch 10/20
# 184/184 [==============================] - 38s 205ms/step - loss: 2.8754 - accuracy: 0.2183 - val_loss: 2.8847 - val_accuracy: 0.2056
# Epoch 11/20
# 184/184 [==============================] - 37s 201ms/step - loss: 2.8333 - accuracy: 0.2193 - val_loss: 2.8214 - val_accuracy: 0.2274
# Epoch 12/20
# 184/184 [==============================] - 35s 188ms/step - loss: 2.8040 - accuracy: 0.2337 - val_loss: 2.8118 - val_accuracy: 0.2151
# Epoch 13/20
# 184/184 [==============================] - 33s 181ms/step - loss: 2.7520 - accuracy: 0.2388 - val_loss: 2.7706 - val_accuracy: 0.2158
# Epoch 14/20
# 184/184 [==============================] - 33s 179ms/step - loss: 2.6988 - accuracy: 0.2564 - val_loss: 2.7517 - val_accuracy: 0.2206
# Epoch 15/20
# 184/184 [==============================] - 34s 185ms/step - loss: 2.6877 - accuracy: 0.2676 - val_loss: 2.6816 - val_accuracy: 0.2573
# Epoch 16/20
# 184/184 [==============================] - 36s 193ms/step - loss: 2.6990 - accuracy: 0.2843 - val_loss: 2.8705 - val_accuracy: 0.2206
# Epoch 17/20
# 184/184 [==============================] - 33s 180ms/step - loss: 2.7091 - accuracy: 0.3038 - val_loss: 2.7174 - val_accuracy: 0.3077
# Epoch 18/20
#  38/184 [=====>........................] - ETA: 20s - loss: 2.6473 - accuracy: 0.3283

# %%
# Plot accuracy and loss curves
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
# Evaluate model
test_data = r'D:\Project\data_kaggle\test'

eval_generator = train_datagen.flow_from_directory(
    test_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

y_true = eval_generator.classes
y_pred = model.predict(eval_generator)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)  # Fix tf.argmax issue

# %%
# Print classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred_classes))

# Plot confusion matrix
conf_mat = confusion_matrix(y_true, y_pred_classes)
class_labels = list(train_generator.class_indices.keys())

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="viridis", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('Actual', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)
plt.show()

# %%
model_version = epochs
next_version = str(int(model_version) + 10)

# %%
import shutil

notebook_filename = f"CNN_{model_version}_ADAM.ipynb"
new_notebook_filename = f"CNN_{next_version}_ADAM.ipynb"

shutil.copy(notebook_filename, new_notebook_filename)
print(f"Notebook copied as {new_notebook_filename}")

# %%
os._exit(00)
