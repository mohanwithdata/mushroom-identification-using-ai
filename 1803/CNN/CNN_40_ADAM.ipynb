# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Input
import os

# %%
# Set dataset path
data_dir = r'D:\Project\data_kaggle\aug\train_augmented'

# %%
batch_size = 32
img_height = 224
img_width = 224
image_size = (img_height, img_width)
epochs = int(input("Enter epochs number: "))
# Out:
# Enter epochs number:  40

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb'  # Force RGB mode
)
# Out:
# Found 7332 images belonging to 8 classes.

# %%
val_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 1463 images belonging to 8 classes.

# %%
model = Sequential([
    Input(shape=(224, 224, 3)),  # Define input explicitly
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(256, activation='relu'),
    Dense(len(train_generator.class_indices), activation='softmax')  # Output layer
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 86528)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               22151424
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 22,246,728
# Trainable params: 22,246,728
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)
# Out:
# Epoch 1/40
# 230/230 [==============================] - 76s 274ms/step - loss: 1.3712 - accuracy: 0.5170 - val_loss: 0.5871 - val_accuracy: 0.7990
# Epoch 2/40
# 230/230 [==============================] - 59s 257ms/step - loss: 0.5201 - accuracy: 0.8249 - val_loss: 0.2957 - val_accuracy: 0.9084
# Epoch 3/40
# 230/230 [==============================] - 55s 238ms/step - loss: 0.2193 - accuracy: 0.9255 - val_loss: 0.0875 - val_accuracy: 0.9713
# Epoch 4/40
# 230/230 [==============================] - 57s 246ms/step - loss: 0.1220 - accuracy: 0.9599 - val_loss: 0.1270 - val_accuracy: 0.9563
# Epoch 5/40
# 230/230 [==============================] - 56s 244ms/step - loss: 0.0612 - accuracy: 0.9821 - val_loss: 0.0259 - val_accuracy: 0.9925
# Epoch 6/40
# 230/230 [==============================] - 56s 244ms/step - loss: 0.0201 - accuracy: 0.9936 - val_loss: 0.0104 - val_accuracy: 0.9986
# Epoch 7/40
# 230/230 [==============================] - 56s 243ms/step - loss: 0.0306 - accuracy: 0.9915 - val_loss: 0.0050 - val_accuracy: 0.9993
# Epoch 8/40
# 230/230 [==============================] - 56s 244ms/step - loss: 0.0561 - accuracy: 0.9813 - val_loss: 0.0161 - val_accuracy: 0.9966
# Epoch 9/40
# 230/230 [==============================] - 56s 243ms/step - loss: 0.0379 - accuracy: 0.9875 - val_loss: 0.0140 - val_accuracy: 0.9966
# Epoch 10/40
# 230/230 [==============================] - 56s 242ms/step - loss: 0.0315 - accuracy: 0.9896 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 11/40
# 230/230 [==============================] - 56s 243ms/step - loss: 0.0822 - accuracy: 0.9727 - val_loss: 0.0153 - val_accuracy: 0.9952
# Epoch 12/40
# 230/230 [==============================] - 57s 245ms/step - loss: 0.0150 - accuracy: 0.9950 - val_loss: 6.0310e-04 - val_accuracy: 1.0000
# Epoch 13/40
# 230/230 [==============================] - 57s 245ms/step - loss: 4.4898e-04 - accuracy: 1.0000 - val_loss: 2.3442e-04 - val_accuracy: 1.0000
# Epoch 14/40
# 230/230 [==============================] - 55s 237ms/step - loss: 1.7915e-04 - accuracy: 1.0000 - val_loss: 1.4945e-04 - val_accuracy: 1.0000
# Epoch 15/40
# 230/230 [==============================] - 57s 245ms/step - loss: 1.2302e-04 - accuracy: 1.0000 - val_loss: 1.0422e-04 - val_accuracy: 1.0000
# Epoch 16/40
# 230/230 [==============================] - 55s 238ms/step - loss: 9.1290e-05 - accuracy: 1.0000 - val_loss: 8.1201e-05 - val_accuracy: 1.0000
# Epoch 17/40
# 230/230 [==============================] - 55s 238ms/step - loss: 7.0787e-05 - accuracy: 1.0000 - val_loss: 6.3399e-05 - val_accuracy: 1.0000
# Epoch 18/40
# 230/230 [==============================] - 55s 238ms/step - loss: 5.6212e-05 - accuracy: 1.0000 - val_loss: 4.9595e-05 - val_accuracy: 1.0000
# Epoch 19/40
# 230/230 [==============================] - 56s 242ms/step - loss: 4.4148e-05 - accuracy: 1.0000 - val_loss: 3.8015e-05 - val_accuracy: 1.0000
# Epoch 20/40
# 230/230 [==============================] - 60s 259ms/step - loss: 3.2708e-05 - accuracy: 1.0000 - val_loss: 2.7461e-05 - val_accuracy: 1.0000
# Epoch 21/40
# 230/230 [==============================] - 57s 245ms/step - loss: 2.3346e-05 - accuracy: 1.0000 - val_loss: 1.9290e-05 - val_accuracy: 1.0000
# Epoch 22/40
# 230/230 [==============================] - 57s 244ms/step - loss: 1.6328e-05 - accuracy: 1.0000 - val_loss: 1.4359e-05 - val_accuracy: 1.0000
# Epoch 23/40
# 230/230 [==============================] - 57s 246ms/step - loss: 1.1995e-05 - accuracy: 1.0000 - val_loss: 1.0345e-05 - val_accuracy: 1.0000
# Epoch 24/40
# 230/230 [==============================] - 57s 245ms/step - loss: 9.0180e-06 - accuracy: 1.0000 - val_loss: 7.4806e-06 - val_accuracy: 1.0000
# Epoch 25/40
# 230/230 [==============================] - 57s 246ms/step - loss: 6.7741e-06 - accuracy: 1.0000 - val_loss: 6.1927e-06 - val_accuracy: 1.0000
# Epoch 26/40
# 230/230 [==============================] - 57s 248ms/step - loss: 5.5267e-06 - accuracy: 1.0000 - val_loss: 4.7345e-06 - val_accuracy: 1.0000
# Epoch 27/40
# 230/230 [==============================] - 59s 256ms/step - loss: 4.5424e-06 - accuracy: 1.0000 - val_loss: 3.8903e-06 - val_accuracy: 1.0000
# Epoch 28/40
# 230/230 [==============================] - 58s 252ms/step - loss: 3.7272e-06 - accuracy: 1.0000 - val_loss: 3.1861e-06 - val_accuracy: 1.0000
# Epoch 29/40
# 230/230 [==============================] - 59s 257ms/step - loss: 3.0657e-06 - accuracy: 1.0000 - val_loss: 2.7074e-06 - val_accuracy: 1.0000
# Epoch 30/40
# 230/230 [==============================] - 58s 251ms/step - loss: 2.6224e-06 - accuracy: 1.0000 - val_loss: 2.2532e-06 - val_accuracy: 1.0000
# Epoch 31/40
# 230/230 [==============================] - 56s 240ms/step - loss: 2.2546e-06 - accuracy: 1.0000 - val_loss: 1.9614e-06 - val_accuracy: 1.0000
# Epoch 32/40
# 230/230 [==============================] - 56s 242ms/step - loss: 1.9105e-06 - accuracy: 1.0000 - val_loss: 1.6623e-06 - val_accuracy: 1.0000
# Epoch 33/40
# 230/230 [==============================] - 61s 262ms/step - loss: 1.6415e-06 - accuracy: 1.0000 - val_loss: 1.4602e-06 - val_accuracy: 1.0000
# Epoch 34/40
# 230/230 [==============================] - 62s 268ms/step - loss: 1.4307e-06 - accuracy: 1.0000 - val_loss: 1.2554e-06 - val_accuracy: 1.0000
# Epoch 35/40
# 230/230 [==============================] - 57s 245ms/step - loss: 1.2462e-06 - accuracy: 1.0000 - val_loss: 1.0635e-06 - val_accuracy: 1.0000
# Epoch 36/40
# 230/230 [==============================] - 59s 254ms/step - loss: 1.0997e-06 - accuracy: 1.0000 - val_loss: 1.0037e-06 - val_accuracy: 1.0000
# Epoch 37/40
# 230/230 [==============================] - 55s 239ms/step - loss: 9.5970e-07 - accuracy: 1.0000 - val_loss: 8.5907e-07 - val_accuracy: 1.0000
# Epoch 38/40
# 230/230 [==============================] - 56s 244ms/step - loss: 8.3910e-07 - accuracy: 1.0000 - val_loss: 7.2039e-07 - val_accuracy: 1.0000
# Epoch 39/40
# 230/230 [==============================] - 57s 245ms/step - loss: 7.4231e-07 - accuracy: 1.0000 - val_loss: 6.2872e-07 - val_accuracy: 1.0000
# Epoch 40/40
# 230/230 [==============================] - 55s 238ms/step - loss: 6.6035e-07 - accuracy: 1.0000 - val_loss: 5.7999e-07 - val_accuracy: 1.0000

# %%
# Plot accuracy and loss curves
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
# Evaluate model
test_data = r'D:\Project\data_kaggle\test'

eval_generator = train_datagen.flow_from_directory(
    test_data,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

y_true = eval_generator.classes
y_pred = model.predict(eval_generator)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)  # Fix tf.argmax issue
# Out:
# Found 190 images belonging to 8 classes.

# %%
# Print classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred_classes))

# Plot confusion matrix
conf_mat = confusion_matrix(y_true, y_pred_classes)
class_labels = list(train_generator.class_indices.keys())
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        28
#            1       0.76      0.76      0.76        21
#            2       0.88      0.84      0.86        25
#            3       0.88      0.96      0.92        23
#            4       0.76      0.76      0.76        21
#            5       0.76      0.83      0.79        23
#            6       0.85      0.88      0.87        26
#            7       0.94      0.74      0.83        23
#
#     accuracy                           0.85       190
#    macro avg       0.85      0.85      0.85       190
# weighted avg       0.86      0.85      0.85       190

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="viridis", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('Actual', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)
plt.show()

# %%
model_version = epochs
next_version = str(int(model_version) + 10)

# %%
import shutil

notebook_filename = f"CNN_{model_version}_ADAM.ipynb"
new_notebook_filename = f"CNN_{next_version}_ADAM.ipynb"

shutil.copy(notebook_filename, new_notebook_filename)
print(f"Notebook copied as {new_notebook_filename}")
# Out:
# Notebook copied as CNN_50_ADAM.ipynb

# %%
os._exit(00)
